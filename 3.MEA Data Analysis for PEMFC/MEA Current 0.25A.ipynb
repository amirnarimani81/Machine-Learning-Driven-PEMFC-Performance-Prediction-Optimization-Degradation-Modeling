# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 210%;text-align: center;border-radius: 10px 70px">
# PEM- Proton Exchange Membrane Fuel Cell<br>
#      MEA Constant Current 0.25A
#
# </center></p></h1>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Liberies
# </center></p></h1>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import io
from functions import *

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Data Loading
# </center></p></h1>

# %%
print(os.getcwd())              # Show current working directory
print(os.listdir())
# Out:
# d:\Chemical Engineering\Chemical Engineering\Softeware\ML\PEMFC simulation\Project 1
# ['functions.py', 'MEA Constant Current 0.25A', 'MEA Constant Current 0.25A.ipynb', 'MEA Constant Voltage 0.6V', 'MEA Constant Voltage 0.6V-2', 'MEA Constant Voltage 0.6V-2.ipynb', 'MEA Constant Voltage 0.6V-3', 'MEA Constant Voltage 0.6V-3.ipynb', 'MEA Constant Voltage 0.6V-4', 'MEA Constant Voltage 0.6V-4.ipynb', 'MEA Constant Voltage 0.6V.ipynb', 'MEA Standard Protocol', 'MEA Standard Protocol (Repeat)', 'MEA Standard Protocol (Repeat).ipynb', 'MEA Standard Protocol.ipynb', 'Report.docx', 'Standard Test of Nafion Membrane 112', 'Standard Test of Nafion Membrane 112.ipynb', '__pycache__', '~$Report.docx']

# %%
path = os.path.join("../","MEA Constant Current 0.25A")

# %%
path = r'D:\Chemical Engineering\Chemical Engineering\Softeware\ML\PEMFC simulation\Project 1\MEA Constant Current 0.25A'

# %%
print("Looking in:", os.path.abspath(path))
print("Files in this folder:", os.listdir(path))
# Out:
# Looking in: D:\Chemical Engineering\Chemical Engineering\Softeware\ML\PEMFC simulation\Project 1\MEA Constant Current 0.25A
# Files in this folder: ['1.csv', '1.names', '2.csv', '2.names', '3.csv', '3.names', '4.csv', '4.names', '5.csv', '5.names', '6.csv', '6.names', 'README.md', 'test.names']

# %% [markdown]
# ## 1- Impedance : End of Each Activation Set

# %%
data = load_data(os.path.join(path,"1.csv"),set_flag=True)

# %%
impedance_plot1(data,set_index=1)

# %%
impedance_plot1(data,set_index=2)

# %% [markdown]
# ## 2- Impedance : Various Voltages (1)

# %%
data = load_data(os.path.join(path,"2.csv"))

# %%
impedance_plot2(data,RH=30,P=5)

# %%
impedance_plot2(data,V=0.3,P=25)

# %%
impedance_plot2(data,RH=30,V=0.3)

# %% [markdown]
# ## 3- Impedance : Various Voltages (2)

# %%
data = load_data(os.path.join(path,"3.csv"))

# %%
impedance_plot2(data,RH=30,P=5)

# %%
impedance_plot2(data,V=0.3,P=25)

# %%
impedance_plot2(data,RH=30,V=0.3)

# %% [markdown]
# ## 4- Polarization : End of Activation Procedure (1)

# %%
data = load_data(os.path.join(path,"4.csv"))

# %%
polarization_plot1(data,RH=30,P=5)

# %%
polarization_plot1(data,RH=30,P=25)

# %% [markdown]
# ## 5- Polarization : End of Activation Procedure (2)

# %%
data = load_data(os.path.join(path,"5.csv"))

# %%
polarization_plot1(data,RH=30,P=5)

# %%
polarization_plot1(data,RH=30,P=25)

# %% [markdown]
# ## 6- Polarization : End of Each Activation Set

# %%
data = load_data(os.path.join(path,"6.csv"))

# %%
polarization_plot2(data,set_index=[5])

# %%
polarization_plot2(data,set_index=[1,2,3,4,5,6,8])

# %% [markdown]
# <div style="border-radius: 5px;
#            -webkit-border-radius: 5px;
#            -moz-border-radius: 5px;
#            font-family: cursive;
#            border: 3px solid #008000;
#            text-align: justify;
#            color: black;
#            font-size: 14px;
#            padding: 5px;
#            background:#F2FFFF">
#
# <p style="text-align: justify; font-family: cursive; font-size: 14px; color : green ; font-weight : bold"> Objective:- PEM fuel cell optimization using Machine Learning </p>
#
#
# <b>Electrochemical Analysis Report</b><br>
#
# 💧 <u>Introduction</u><br>
# The provided plots represent electrochemical impedance spectroscopy (EIS) and polarization curve data collected under various experimental conditions, including different relative humidity (RH) levels, pressures (P), and cell voltages (V). These measurements are critical for understanding the performance characteristics of electrochemical systems, likely fuel cells or similar devices.
#
# 🔍 <u>Data Interpretation</u><br>
#
# <u>1. EIS Analysis (Nyquist Plots)</u><br>
# • Voltage Variation: Semicircular arcs decrease with increasing voltage (0.3V→0.8V), indicating reduced charge transfer resistance<br>
# • RH Variation: Higher RH (30%→100%) leads to smaller arcs, demonstrating hydration's critical role<br>
# • Pressure Effects: 25 psig shows lower impedance than 5 psig, improving mass transport<br>
#
# <u>2. Polarization Curve Analysis</u><br>
# • All curves show typical fuel cell behavior with distinct regions<br>
# • Higher pressures (25 psig) yield better performance across current densities<br>
# • Performance varies between different sets, suggesting configuration differences<br>
#
# 📌 <u>Key Findings</u><br>
# 1. Humidity Impact: RH ≥50% significantly improves performance<br>
# 2. Voltage Effects: 0.7-0.8V range shows best impedance characteristics<br>
# 3. Pressure Benefits: 25 psig outperforms 5 psig in all aspects<br>
# 4. Optimal Conditions: High RH + moderate pressure + 0.7-0.8V<br>
#
# ✅ <u>Conclusions</u><br>
# • System is highly sensitive to RH, pressure, and voltage conditions<br>
# • Both charge transfer and mass transport improve with proper conditioning<br>
# • Higher pressure extends useful current density range<br>
# • Recommended operation: ≥50% RH, 25 psig, 0.7-0.8V<br>
#
# 🔮 <u>Recommendations</u><br>
# 1. Investigate durability at high humidity/pressure<br>
# 2. Explore intermediate RH (50-100%) and pressure (5-25 psig) points<br>
# 3. Examine causes of performance variations between sets<br>
# 4. Address practical implementation challenges<br>
#
# </div>
