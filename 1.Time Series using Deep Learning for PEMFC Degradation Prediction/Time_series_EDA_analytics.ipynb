# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 210%;text-align: center;border-radius: 10px 70px">
#     Time Series Using Deep Learning for Proton Exchange Membrane Fuel Cell (PEMFC) Degradation Prediction
#
# </center></p></h1>

# %% [markdown]
# <a href=""  alt="Open In Clob"><a>

# %% [markdown]
# <center> <img src="https://cienciadedatos.net/images/forecasting_multi-step_en.gif" width="500" height="300"> </center>

# %% [markdown]
# <a class="anchor" id="setup"></a>
# <br>
# <br>
# <br>
# <font style="font-family:Gabriola; font-size:300%;">1️⃣ Step 1 | About Dataset </font><br>
#  <br>
# <br>

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: cursive;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:16px;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ Time-Series ML Framework for PEMFC Degradation & RUL Prediction
#   </p>
#
#   <p style="font-weight:bold;">🎯 Aim</p>
#   <p>
#     Design and deploy a <b>robust time-series machine learning framework</b> to
#     predict <b>PEM fuel cell degradation</b> and estimate
#     <b>Remaining Useful Life (RUL)</b>, emphasizing
#     <b>deep sequential models</b> and benchmarking against
#     <b>classical statistical approaches</b>.
#   </p>
#
#   <p style="font-weight:bold;">📌 Overview</p>
#   <p>
#     This project integrates <b>electrochemical data analysis</b> with
#     <b>machine learning–based prognostics</b> to model long-term performance
#     degradation in <b>Proton Exchange Membrane Fuel Cells (PEMFCs)</b>.
#   </p>
#
#   <ul style="margin-left:15px;">
#     <li>🧠 Deep learning: <b>RNN, GRU, LSTM</b></li>
#     <li>📊 Statistical baselines: <b>ARIMA, SARIMA, Prophet</b></li>
#     <li>⚙️ Automated hyperparameter tuning (<b>Optuna</b>)</li>
#     <li>🔁 End-to-end ETL, modeling, and evaluation pipeline</li>
#     <li>🚀 Interactive deployment via <b>Streamlit</b></li>
#   </ul>
#
#   <p style="font-weight:bold;">🎯 Objectives</p>
#   <ul style="margin-left:15px;">
#     <li>Capture long-term voltage degradation trends</li>
#     <li>Estimate RUL with minimal forecasting bias</li>
#     <li>Quantitatively compare classical vs deep learning models</li>
#     <li>Enable reusable prognostics workflows for real systems</li>
#   </ul>
#
#   <p style="font-weight:bold;">🧠 Modeling Strategy</p>
#   <ul style="margin-left:15px;">
#     <li><b>Sequence-to-one</b> supervised learning formulation</li>
#     <li>Lag-based temporal windows for degradation dynamics</li>
#     <li>Regularized deep networks for long-horizon prediction</li>
#     <li>Model generalization and transferability assessment</li>
#   </ul>
#
#   <p style="font-weight:bold;">⚙️ Pipeline</p>
#   <ul style="margin-left:15px;">
#     <li>Data cleaning, smoothing, and outlier handling</li>
#     <li>Feature engineering & normalization</li>
#     <li>Train / validation / test split</li>
#     <li>Evaluation using <b>RMSE, MAE, MAPE, R², and RUL error</b></li>
#   </ul>
#
#   <p style="font-weight:bold;"> Electrochemical Data Support</p>
#   <ul style="margin-left:15px;">
#     <li>Excel / CSV upload for experimental fuel cell data</li>
#     <li><b>EIS</b> (Nyquist analysis), <b>CV</b>, and <b>polarization curves</b></li>
#     <li>Condition-based filtering (RH, pressure, voltage, test set)</li>
#     <li>Multi-curve visualization using Python & Matplotlib</li>
#   </ul>
#
#   <p style="font-weight:bold;">🚀 Deployment</p>
#   <ul style="margin-left:15px;">
#     <li>Interactive Streamlit interface</li>
#     <li>Real-time degradation & RUL prediction</li>
#     <li>Dynamic performance and trend visualization</li>
#   </ul>
#
#   <p style="font-weight:bold;">🧩 Skills Highlighted</p>
#   <ul style="margin-left:15px;">
#     <li>Time-series ML & deep learning</li>
#     <li>Electrochemical data analysis</li>
#     <li>Prognostics & health management (PHM)</li>
#     <li>Scientific visualization & deployment</li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: cursive;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:16px;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#    IEEE PHM 2014 PEMFC Dataset Description
#   </p>
#
#   <p style="font-weight:bold;">📌 Dataset Overview</p>
#   <p>
#     The <b>IEEE PHM 2014 Data Challenge dataset</b> contains long-term operational
#     measurements acquired from a <b>proton exchange membrane fuel cell (PEMFC) stack</b>
#     operating under aging conditions. The dataset was designed to support
#     <b>prognostics and health management (PHM)</b> research, with a strong focus on
#     <b>degradation modeling</b> and <b>Remaining Useful Life (RUL) prediction</b>.
#   </p>
#
#   <p style="font-weight:bold;">🔌 Electrical Measurements</p>
#   <ul style="margin-left:15px;">
#     <li><b>U1 – U5:</b> Individual single-cell voltages (V)</li>
#     <li><b>Utot:</b> Stack voltage (V)</li>
#     <li><b>I:</b> Stack current (A)</li>
#     <li><b>J:</b> Current density (A/cm²)</li>
#   </ul>
#
#   <p style="font-weight:bold;">🌡️ Thermal Measurements</p>
#   <ul style="margin-left:15px;">
#     <li><b>TinH2 / ToutH2:</b> Hydrogen inlet / outlet temperature (°C)</li>
#     <li><b>TinAIR / ToutAIR:</b> Air inlet / outlet temperature (°C)</li>
#     <li><b>TinWAT / ToutWAT:</b> Cooling water inlet / outlet temperature (°C)</li>
#   </ul>
#
#   <p style="font-weight:bold;">🌬️ Pressure Measurements</p>
#   <ul style="margin-left:15px;">
#     <li><b>PinH2 / PoutH2:</b> Hydrogen inlet / outlet pressure (mbara)</li>
#     <li><b>PinAIR / PoutAIR:</b> Air inlet / outlet pressure (mbara)</li>
#   </ul>
#
#   <p style="font-weight:bold;">💨 Flow Rate Measurements</p>
#   <ul style="margin-left:15px;">
#     <li><b>DinH2 / DoutH2:</b> Hydrogen inlet / outlet flow rate (L/min)</li>
#     <li><b>DinAIR / DoutAIR:</b> Air inlet / outlet flow rate (L/min)</li>
#     <li><b>DWAT:</b> Cooling water flow rate (L/min)</li>
#   </ul>
#
#   <p style="font-weight:bold;">💧 Humidity Measurement</p>
#   <ul style="margin-left:15px;">
#     <li><b>HrAIRFC:</b> Estimated inlet air relative humidity (%)</li>
#   </ul>
#
#   <p style="font-weight:bold;">🎯 Relevance for Degradation & RUL Modeling</p>
#   <ul style="margin-left:15px;">
#     <li>Captures <b>long-term voltage degradation behavior</b></li>
#     <li>Supports <b>multivariate time-series learning</b></li>
#     <li>Enables benchmarking of <b>classical</b> and <b>deep learning</b> prognostic models</li>
#     <li>Reflects realistic <b>thermal, fluidic, and electrochemical coupling</b></li>
#   </ul>
#
# </div>

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import plotly.subplots as sp
import plotly.graph_objects as go


from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing, Holt
from statsmodels.tsa.seasonal import seasonal_decompose
import itertools
from prophet import Prophet
from scipy import stats
import optuna
from tensorflow.keras.backend import clear_session

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout,GRU,Conv1D, MaxPooling1D, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from scipy.signal import savgol_filter
from math import sqrt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#     Data Loading
# </center></p></h1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
csv_file = '/content/drive/MyDrive/Time Series Analysis/FC1_Ageing_part1.csv'

df1 = pd.read_csv(csv_file, encoding='cp1252')

df1.head()
# Out:
#    Time (h)  U1 (V)  U2 (V)  U3 (V)  U4 (V)  U5 (V)  Utot (V)  J (A/cm²)  \
# 0  0.000000   0.670   0.663   0.664   0.662   0.658     3.317    0.70164
# 1  0.000156   0.670   0.663   0.663   0.662   0.659     3.317    0.70164
# 2  0.000321   0.670   0.663   0.663   0.662   0.658     3.316    0.70168
# 3  0.000475   0.669   0.663   0.663   0.662   0.659     3.316    0.70164
# 4  0.000624   0.669   0.663   0.663   0.662   0.659     3.316    0.70159
#
#     I (A)  TinH2 (°C)  ...  PinAIR (mbara)  PoutAIR (mbara)  PoutH2 (mbara)  \
# 0  70.164      25.930  ...        1302.204         1269.602        1305.319
# 1  70.164      25.945  ...        1301.863         1269.829        1305.205
# 2  70.168      25.943  ...        1302.261         1269.773        1305.547
# 3  70.164      25.945  ...        1301.863         1269.886        1305.775
# 4  70.159      25.939  ...        1302.034         1269.659        1305.661
#
# ...

# %%
csv_file1 = '/content/drive/MyDrive/Time Series Analysis/FC1_Ageing_part2.csv'

df2 = pd.read_csv(csv_file1, encoding='cp1252')

df2.head()
# Out:
#      Time (h)  U1 (V)  U2 (V)  U3 (V)  U4 (V)  U5 (V)  Utot (V)  J (A/cm²)  \
# 0  497.152976   0.657   0.654   0.650   0.653    0.65     3.264    0.70188
# 1  497.161366   0.656   0.653   0.649   0.653    0.65     3.261    0.70183
# 2  497.169755   0.657   0.653   0.649   0.653    0.65     3.262    0.70193
# 3  497.178144   0.657   0.654   0.650   0.654    0.65     3.265    0.70183
# 4  497.186535   0.657   0.654   0.650   0.654    0.65     3.265    0.70178
#
#     I (A)  TinH2 (°C)  ...  PinAIR (mbara)  PoutAIR (mbara)  PoutH2 (mbara)  \
# 0  70.188      28.812  ...        1298.336         1266.984        1302.239
# 1  70.183      28.806  ...        1298.791         1268.008        1296.651
# 2  70.193      28.813  ...        1298.848         1267.325        1293.913
# 3  70.183      28.815  ...        1298.279         1267.098        1302.296
# 4  70.178      28.812  ...        1296.800         1265.675        1305.718
#
# ...

# %%
csv_file2 = '/content/drive/MyDrive/Time Series Analysis/FC1_Ageing_part3.csv'

df3 = pd.read_csv(csv_file2, encoding='cp1252')

df3.head()
# Out:
#       Time (h)  U1 (V)  U2 (V)  U3 (V)  U4 (V)  U5 (V)  Utot (V)  J (A/cm²)  \
# 0  1046.900000   0.652   0.648   0.641   0.649   0.642     3.232    0.70442
# 1  1046.908406   0.652   0.647   0.641   0.649   0.642     3.231    0.70447
# 2  1046.916783   0.652   0.648   0.641   0.649   0.642     3.232    0.70447
# 3  1046.925187   0.653   0.649   0.642   0.650   0.642     3.236    0.70447
# 4  1046.933558   0.653   0.648   0.641   0.649   0.641     3.232    0.70447
#
#     I (A)  TinH2 (°C)  ...  PinAIR (mbara)  PoutAIR (mbara)  PoutH2 (mbara)  \
# 0  70.442      27.849  ...        1296.232         1266.017        1295.282
# 1  70.447      27.859  ...        1298.279         1267.041        1298.190
# 2  70.447      27.855  ...        1305.617         1275.975        1302.639
# 3  70.447      27.858  ...        1302.773         1272.106        1305.775
# 4  70.447      27.859  ...        1300.953         1270.398        1299.160
#
# ...

# %%
df=pd.concat([df1, df2, df3])
df.head()
# Out:
#    Time (h)  U1 (V)  U2 (V)  U3 (V)  U4 (V)  U5 (V)  Utot (V)  J (A/cm²)  \
# 0  0.000000   0.670   0.663   0.664   0.662   0.658     3.317    0.70164
# 1  0.000156   0.670   0.663   0.663   0.662   0.659     3.317    0.70164
# 2  0.000321   0.670   0.663   0.663   0.662   0.658     3.316    0.70168
# 3  0.000475   0.669   0.663   0.663   0.662   0.659     3.316    0.70164
# 4  0.000624   0.669   0.663   0.663   0.662   0.659     3.316    0.70159
#
#     I (A)  TinH2 (°C)  ...  PinAIR (mbara)  PoutAIR (mbara)  PoutH2 (mbara)  \
# 0  70.164      25.930  ...        1302.204         1269.602        1305.319
# 1  70.164      25.945  ...        1301.863         1269.829        1305.205
# 2  70.168      25.943  ...        1302.261         1269.773        1305.547
# 3  70.164      25.945  ...        1301.863         1269.886        1305.775
# 4  70.159      25.939  ...        1302.034         1269.659        1305.661
#
# ...

# %%
df.columns
# Out:
# Index(['Time (h)', 'U1 (V)', 'U2 (V)', 'U3 (V)', 'U4 (V)', 'U5 (V)',
#        'Utot (V)', 'J (A/cm²)', 'I (A)', 'TinH2 (°C)', 'ToutH2 (°C)',
#        'TinAIR (°C)', 'ToutAIR (°C)', 'TinWAT (°C)', 'ToutWAT (°C)',
#        'PinAIR (mbara)', 'PoutAIR (mbara)', 'PoutH2 (mbara)', 'PinH2 (mbara)',
#        'DinH2 (l/mn)', 'DoutH2 (l/mn)', 'DinAIR (l/mn)', 'DoutAIR (l/mn)',
#        'DWAT (l/mn)', 'HrAIRFC (%)'],
#       dtype='object')

# %%
mapping = {
    'U1 (V)': 'single-cell voltage1 (V)',
    'U2 (V)': 'single-cell voltage2 (V)',
    'U3 (V)': 'single-cell voltage3 (V)',
    'U4 (V)': 'single-cell voltage4 (V)',
    'U5 (V)': 'single-cell voltage5 (V)',
    'Utot (V)': 'stack voltage (V)',
    'I (A)': 'stack current (A)',
    'J (A/cm²)': 'current density (A/cm²)',
    'TinH2 (°C)': 'hydrogen inlet temperature (°C)',
    'DinH2 (l/mn)': 'hydrogen inlet flow rate (L/min)',
    'DoutH2 (l/mn)': 'hydrogen outlet flow rate (L/min)',
    'DinAIR (l/mn)': 'air inlet flow rate (L/min)',
    'DoutAIR (l/mn)': 'air outlet flow rate (L/min)'
}

# %%
df = df.rename(columns=mapping)

# %%
df.head()
# Out:
#           single-cell voltage1 (V)  single-cell voltage2 (V)  \
# Time (h)
# 0.000000                     0.670                     0.663
# 0.000156                     0.670                     0.663
# 0.000321                     0.670                     0.663
# 0.000475                     0.669                     0.663
# 0.000624                     0.669                     0.663
#
#           single-cell voltage3 (V)  single-cell voltage4 (V)  \
# Time (h)
# 0.000000                     0.664                     0.662
# 0.000156                     0.663                     0.662
# 0.000321                     0.663                     0.662
# 0.000475                     0.663                     0.662
# 0.000624                     0.663                     0.662
#
#           single-cell voltage5 (V)  stack voltage (V)  \
# Time (h)
# 0.000000                     0.658              3.317
# 0.000156                     0.659              3.317
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def check_df(df, name="Dataset", head=5):
    print("\n" + "="*60)
    print(f"📊 DATASET OVERVIEW: {name}")
    print("="*60)

    # 1. Shape
    print("\n📌 SHAPE")
    print(f"Rows: {df.shape[0]} | Columns: {df.shape[1]}")

    # 2. Data Types (per column)
    print("\n📌 DATA TYPES (PER COLUMN)")
    print(df.dtypes)

    # 3. Data Type Summary
    print("\n📌 DATA TYPE SUMMARY")
    print(df.dtypes.value_counts())

    # 4. Info
    print("\n📌 INFO")
    df.info()

    # 5. Head
    print("\n📌 HEAD")
    display(df.head(head))

    # 6. Tail
    print("\n📌 TAIL")
    display(df.tail(head))

    # 7. Missing Values
    print("\n📌 MISSING VALUES")
    print(df.isnull().sum())

    # 8. Duplicate Rows
    print("\n📌 DUPLICATE ROWS")
    print(f"Number of duplicate rows: {df.duplicated().sum()}")

    # 9. Descriptive Statistics (numeric only)
    print("\n📌 DESCRIPTIVE STATISTICS (NUMERIC)")
    display(df.describe())

# %%
check_df(df, "PEMFC")
# Out:
# ...
# 📊 DATASET OVERVIEW: PEMFC
# ...
#
# 📌 SHAPE
# Rows: 143862 | Columns: 25
#
# 📌 DATA TYPES (PER COLUMN)
# Time (h)                             float64
# single-cell voltage1 (V)             float64
# single-cell voltage2 (V)             float64
# single-cell voltage3 (V)             float64
# single-cell voltage4 (V)             float64
# single-cell voltage5 (V)             float64
# stack voltage (V)                    float64
# current density (A/cm²)              float64
# stack current (A)                    float64
# hydrogen inlet temperature (°C)      float64
# ToutH2 (°C)                          float64
# TinAIR (°C)                          float64
# ToutAIR (°C)                         float64
# TinWAT (°C)                          float64
# ToutWAT (°C)                         float64
# PinAIR (mbara)                       float64
# PoutAIR (mbara)                      float64
# PoutH2 (mbara)                       float64
# PinH2 (mbara)                        float64
# ...

# %%
#percentage of missing values in train_df

missing_percentages = df.isnull().sum()/ len(df1) * 100

print(missing_percentages)
# Out:
# Time (h)                             0.0
# single-cell voltage (V)              0.0
# single-cell voltage (V)              0.0
# single-cell voltage (V)              0.0
# single-cell voltage (V)              0.0
# single-cell voltage (V)              0.0
# stack voltage (V)                    0.0
# current density (A/cm²)              0.0
# stack current (A)                    0.0
# hydrogen inlet temperature (°C)      0.0
# ToutH2 (°C)                          0.0
# TinAIR (°C)                          0.0
# ToutAIR (°C)                         0.0
# TinWAT (°C)                          0.0
# ToutWAT (°C)                         0.0
# PinAIR (mbara)                       0.0
# PoutAIR (mbara)                      0.0
# PoutH2 (mbara)                       0.0
# PinH2 (mbara)                        0.0
# hydrogen inlet flow rate (L/min)     0.0
# hydrogen outlet flow rate (L/min)    0.0
# air inlet flow rate (L/min)          0.0
# air outlet flow rate (L/min)         0.0
# ...

# %% [markdown]
# # Duplicates

# %%
dupes=df1.duplicated().sum()

print(dupes)
# Out:
# 0

# %%
df[df['stack voltage (V)'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Time (h), single-cell voltage1 (V), single-cell voltage2 (V), single-cell voltage3 (V), single-cell voltage4 (V), single-cell voltage5 (V), stack voltage (V), current density (A/cm²), stack current (A), hydrogen inlet temperature (°C), ToutH2 (°C), TinAIR (°C), ToutAIR (°C), TinWAT (°C), ToutWAT (°C), PinAIR (mbara), PoutAIR (mbara), PoutH2 (mbara), PinH2 (mbara), hydrogen inlet flow rate (L/min), hydrogen outlet flow rate (L/min), air inlet flow rate (L/min), air outlet flow rate (L/min), DWAT (l/mn), HrAIRFC (%)]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Remove Outliers</p>
# </div>

# %%
plt.figure(figsize=(8, 10))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %%
Q1 = df["stack voltage (V)"].quantile(0.25)
Q3 = df["stack voltage (V)"].quantile(0.75)
IQR = Q3 - Q1

# Condition for outliers
outliers = (df["stack voltage (V)"] < (Q1 - 1.5 * IQR)) | \
           (df["stack voltage (V)"] > (Q3 + 1.5 * IQR))

# Scatter plot with outliers in red
sns.scatterplot(x=df.index, y=df["stack voltage (V)"], label="Normal", color='blue')
sns.scatterplot(x=df.index[outliers], y=df["stack voltage (V)"][outliers],
                color="red", s=100, label="Outliers")
plt.xlabel("Sample Index")
plt.ylabel("Stack voltage (V)")
plt.title("Scatter Plot with Outliers in Red")
plt.legend()
plt.show()

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Missing Handking
# </center></p></h1>

# %%
# Fill missing values using ffill method
df.fillna(method='ffill', inplace=True)  # Forward fill to maintain continuity
df.info() # Verify that there are no missing values left

# %%
plt.figure(figsize=(22,10))
plt.xticks(size=20,color='grey')
plt.tick_params(size=12,color='grey')
plt.title('Finding Null Values Using Heatmap\n',color='grey',size=30)
sns.heatmap(df.isnull(),
            yticklabels=False,
            cbar=False,
            cmap='PuBu_r',
            )
plt.show()

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Distribution and anlaysis data
# </center></p></h1>

# %%
plt.figure(figsize=(20, 6))

df.groupby("Time (h)")["stack voltage (V)"].mean().plot(
    color="darkred",
    label="Mean Stack Voltage"
)

plt.xlabel("Time (h)")
plt.ylabel("Stack Voltage (V)")
plt.title("PEMFC Stack Voltage Degradation Over Time")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: 'Segoe UI', Arial, sans-serif;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:16px;
#      line-height:1.6;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ PEMFC Stack Voltage Degradation Over Time
#   </p>
#
#   <p>
#     This plot shows the <b>voltage decay of a PEMFC stack</b> over extended operation
#     (up to 1200 hours). The x-axis represents <b>operating time (h)</b>, while the y-axis
#     shows the <b>stack voltage (V)</b>, typically starting near 3.35 V and decreasing
#     toward 3.10 V over the stack’s life.
#   </p>
#
#   <p>
#     Initially, the stack operates near maximum voltage, reflecting uniform reactant
#     distribution, well-hydrated membranes, and healthy catalysts. Over time, the voltage
#     gradually declines due to <b>membrane drying or flooding</b>, <b>catalyst degradation</b>,
#     <b>carbon corrosion</b>, and <b>electrode contamination</b>. The curve often shows an
#     <b>initial break-in drop</b>, followed by a <b>steady, slow decline</b>, with potential
#     <b>accelerated drops near end-of-life</b>. Temporary voltage recoveries may occur due
#     to improved hydration or transient operating conditions.
#   </p>
#
#   <p>
#     From an engineering perspective, the slope of the degradation curve quantifies
#     stack durability and informs <b>Remaining Useful Life (RUL) estimation</b>,
#     <b>maintenance scheduling</b>, and <b>operating strategies</b>. Sudden dips or
#     stepwise drops may indicate localized failures or system events, while smooth
#     declines reflect normal aging. This plot provides a concise visualization of
#     PEMFC performance and long-term reliability.
#   </p>
#
# </div>

# %%
df[
    (df["Time (h)"] >= 800) & (df["Time (h)"] <= 1100)
]["stack voltage (V)"].plot(
    grid=True,
    marker=".",
    figsize=(8, 3.5)
)

plt.xlabel("Time (h)")
plt.ylabel("Stack Voltage (V)")
plt.title("Stack Voltage Degradation (800–1100 h)")
plt.show()

# %%
sns.barplot(x='single-cell voltage1 (V)', y='stack voltage (V)', data=df)
# Out:
# <Axes: xlabel='single-cell voltage1 (V)', ylabel='stack voltage (V)'>

# %% [markdown]
# # Check min and max date for Time period

# %%
print(df["Time (h)"].min(), df["Time (h)"].max())
# Length of data
print(len(df))
# Out:
# 0.0 1154.213356
# 143862

# %% [markdown]
# # Distribution of Stack Voltage in a PEMFC Stack

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['stack voltage (V)'], kde=True, color='orange', bins=30)
plt.title('Distribution of stack voltage (V)')
plt.xlabel('stack voltage (V) ')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: 'Segoe UI', Arial, sans-serif;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:16px;
#      line-height:1.6;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ Distribution of Stack Voltage in a PEMFC Stack
#   </p>
#
#   <p>
#     <b>Figure </b> presents the frequency distribution of <b>stack voltage (V)</b> in a
#     PEMFC stack. The x-axis represents measured stack voltage (~3.10–3.35 V), while the
#     y-axis indicates the number of occurrences of each voltage range.
#   </p>
#
#   <p>
#     The dominant peak reflects the most common operating voltage, indicating the typical
#     electrochemical working point. A narrow distribution suggests stable operation, while
#     a wider spread indicates higher voltage variability due to load changes, cell
#     imbalance, or aging.
#   </p>
#
#   <p>
#     The shape of the histogram provides further insight: a Gaussian-like profile indicates
#     normal fluctuations around a steady state, skewness or peak shifts imply gradual
#     degradation, and multiple peaks reflect transitions between operating regimes.
#   </p>
#
#   <p>
#     Monitoring changes in the stack voltage distribution over time can reveal early signs
#     of performance degradation, making it a key metric for <b>health monitoring</b> and
#     <b>RUL prediction</b> in PEMFC systems.
#   </p>
#
# </div>

# %% [markdown]
# # Cell Voltage Imbalance Over Time in a PEMFC Stack\

# %%
cell_cols = [
    'single-cell voltage1 (V)',
    'single-cell voltage2 (V)',
    'single-cell voltage3 (V)',
    'single-cell voltage4 (V)',
    'single-cell voltage5 (V)'
]

df['cell_voltage_std'] = df[cell_cols].std(axis=1)

# %%
plt.figure(figsize=(10,4))
plt.plot(df['Time (h)'], df['cell_voltage_std'], color='darkred')
plt.xlabel('Time (h)')
plt.ylabel('Cell Voltage Std (V)')
plt.title('Cell Voltage Imbalance Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: 'Segoe UI', Arial, sans-serif;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:18px;
#      line-height:1.6;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ Evolution of Cell Voltage Imbalance as a Degradation Indicator in PEMFC Systems
#   </p>
#
#   <p>
#     Figure  presents the evolution of <b>cell voltage imbalance</b> in a
#     <b>proton exchange membrane fuel cell (PEMFC) stack</b> over an operating period
#     of up to <b>1200 hours</b>. The imbalance is quantified using the
#     <b>standard deviation of individual cell voltages</b>, which serves as a
#     sensitive indicator of <b>stack-level degradation</b>.
#   </p>
#
#   <p style="font-weight:bold; color:#005C2A;">📐 Axes Description</p>
#   <ul style="margin-left:18px;">
#     <li>
#       <b>X-axis:</b> Time (h), representing cumulative PEMFC operating hours and aging.
#     </li>
#     <li>
#       <b>Y-axis:</b> Cell Voltage Standard Deviation (V), indicating the degree of
#       non-uniform electrochemical performance among cells.
#       <ul style="margin-left:18px;">
#         <li>Lower values correspond to a well-balanced stack.</li>
#         <li>Higher values indicate increasing cell-to-cell heterogeneity.</li>
#       </ul>
#     </li>
#   </ul>
#
#   <p style="font-weight:bold; color:#005C2A;">📉 Observed Degradation Trend</p>
#   <p>
#     At the beginning of operation, the PEMFC stack exhibits minimal voltage dispersion
#     (approximately <b>0.002–0.003 V</b>), reflecting uniform membrane hydration,
#     balanced reactant distribution, and healthy catalyst layers. As operation
#     progresses, the voltage standard deviation gradually increases, potentially
#     reaching values on the order of <b>0.02–0.025 V</b> after prolonged operation
#     (around <b>1200 h</b>).
#   </p>
#
#   <p>
#     This increasing imbalance is attributed to non-uniform degradation mechanisms,
#     including:
#   </p>
#   <ul style="margin-left:18px;">
#     <li>Local membrane dehydration or thinning</li>
#     <li>Spatially heterogeneous catalyst degradation and electrochemical surface area (ECSA) loss</li>
#     <li>Variations in gas transport, water management, and thermal conditions</li>
#   </ul>
#
#   <p style="font-weight:bold; color:#005C2A;">⚙️ Engineering Implications</p>
#   <p>
#     Rising voltage imbalance is a critical degradation marker in PEMFC stacks. Cells
#     operating at lower voltages experience higher local overpotentials, which
#     accelerate degradation processes and increase the risk of premature failure.
#     Consequently, the cell voltage standard deviation provides early insight into
#     internal stack health, often preceding observable declines in overall stack
#     voltage.
#   </p>
#
#   <p style="font-weight:bold; color:#005C2A;">🔮 Relevance to Prognostics</p>
#   <p>
#     The monotonic increase—and potential late-life acceleration—of voltage imbalance
#     makes this metric particularly suitable for <b>degradation tracking</b>,
#     <b>Remaining Useful Life (RUL) prediction</b>, and <b>health monitoring</b> within
#     PEMFC prognostics and PHM frameworks.
#   </p>
#
# </div>

# %% [markdown]
# # Impact of Thermal Stress on PEMFC Stack Voltage

# %%
df['delta_T_air'] = df['ToutAIR (°C)'] - df['TinAIR (°C)']

plt.figure(figsize=(6,5))
plt.scatter(
    df['delta_T_air'],
    df['stack voltage (V)'],
    s=5, alpha=0.3, color='purple'
)
plt.xlabel('ΔT Air (°C)')
plt.ylabel('Stack Voltage (V)')
plt.title('Thermal Stress vs Voltage Degradation')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius:6px;
#      font-family: 'Segoe UI', Arial, sans-serif;
#      border:3px solid #007A33;
#      background:#F6FFF9;
#      color:#111;
#      font-size:14px;
#      padding:16px;
#      line-height:1.6;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ Impact of Thermal Stress on PEMFC Stack Voltage
#   </p>
#
#   <p>
#     This plot illustrates the relationship between <b>thermal stress (ΔT Air, °C)</b> and
#     <b>stack voltage (V)</b> in a PEMFC system. The x-axis represents the temperature
#     difference across the stack or between inlet and outlet air, while the y-axis shows
#     the stack voltage under operating conditions.
#   </p>
#
#   <p>
#     As ΔT increases, representing greater thermal gradients or uneven heating, the stack
#     voltage generally decreases. Low ΔT corresponds to uniform temperature distribution
#     and stable voltage, whereas high ΔT introduces hotspots, accelerates membrane
#     drying/flooding, reduces catalyst activity, and increases internal resistance,
#     contributing to voltage drop.
#   </p>
#
#   <p>
#     The trend shows a <b>negative correlation</b>: as thermal stress rises, stack
#     performance declines. The relationship may be nonlinear, with minimal voltage impact
#     at small ΔT and sharper losses at higher ΔT. Clusters in the data may reflect
#     different operating conditions such as load or humidity variations.
#   </p>
#
#   <p>
#     <b>Engineering Implications:</b> The plot highlights the importance of thermal
#     management, guiding airflow design, cooling strategies, and operational limits.
#     Monitoring ΔT helps predict long-term stack degradation and supports durability
#     optimization, ensuring reliable PEMFC performance under real-world thermal conditions.
#   </p>
#
# </div>

# %% [markdown]
# # Time-Series Trends (Voltage Degradation)

# %%
plt.figure(figsize=(16,5))
plt.plot(df['Time (h)'], df['stack voltage (V)'], label='Stack Voltage')
plt.plot(df['Time (h)'], df['single-cell voltage1 (V)'], label='Cell 1')
plt.plot(df['Time (h)'], df['single-cell voltage2 (V)'], label='Cell 2')
plt.xlabel("Time (h)")
plt.ylabel("Voltage (V)")
plt.title("Stack and Cell Voltage Degradation Over Time")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius:6px; font-family: cursive; border:3px solid #007A33; background:#F6FFF9; color:#111; font-size:14px; padding:16px;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#     ⚡ Stack and Cell Voltage Degradation in PEMFCs
#   </p>
#
#   <p>
#     Figure shows the evolution of both <b>stack voltage</b> and <b>individual cell voltages</b> over 1200 hours of PEMFC operation. The y-axis ranges from 0 to 3.5 V, capturing the full stack voltage (~3.0–3.5 V) and single-cell voltages (~0.6–0.8 V).
#   </p>
#
#   <p style="font-weight:bold;">📊 Observed Trends</p>
#   <ul style="margin-left:15px;">
#     <li>Both stack and cell voltages gradually decline over time.</li>
#     <li>Individual cell voltages often degrade faster than the stack, creating <b>voltage imbalance</b>.</li>
#     <li>The gap between stack and cell voltages highlights weak cells limiting overall performance.</li>
#   </ul>
#
#   <p style="font-weight:bold;">⚙️ Engineering Insights</p>
#   <ul style="margin-left:15px;">
#     <li>Early identification of failing cells through voltage gaps.</li>
#     <li>Supports <b>Remaining Useful Life (RUL)</b> prediction and stack health monitoring.</li>
#     <li>Assesses effectiveness of cell balancing and conditioning strategies.</li>
#   </ul>
#
#   <p style="font-weight:bold;">📝 Summary</p>
#   <p>
#     This plot provides a concise view of PEMFC degradation, illustrating how individual cell behavior drives overall stack health and informing maintenance and operational strategies.
#   </p>
#
# </div>

# %% [markdown]
# ## Correlation Analysis

# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_price = correlation_matrix['stack voltage (V)'].sort_values(ascending=False).head(15)
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_price.to_frame(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation PEMFC')
plt.show()

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Feature Engineering
# </center></p></h1>

# %% [markdown]
# # Volatility Plot

# %%
df['Value_stack voltage (V)'] = df['stack voltage (V)'].pct_change()
window_size = 100
df_100 = df['Value_stack voltage (V)'].rolling(window = window_size).std()


#plotting
plt.figure(figsize = (20,6))
plt.plot(df.index , df_100 , label = 'stack voltage (V)' , color = 'blue')
plt.title('Volatility of stack voltage (V) in a 100 day window')
plt.xlabel('Time (h)')
plt.ylabel('stack voltage (V)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000; text-align: justify; color: black; font-size: 14px; padding: 10px; background:#F2FFFF;">
#     <div style="border-radius:6px; font-family: cursive; border:3px solid #007A33; background:#F6FFF9; color:#111; font-size:14px; padding:16px;">
#
#   <p style="color:#005C2A; font-weight:bold; font-size:16px;">
#             ⚡ Stack Voltage Volatility Over Time in PEMFCs
#         </p>
#
#  <p style="font-weight:bold;">📌 Overview</p>
#   <p>
#             This plot presents the stack voltage of a Proton Exchange Membrane Fuel Cell (PEMFC) over extended operation, measured in hours (Time (h)). It highlights both short-term fluctuations and long-term trends to assess operational stability.
#    </p>
#
#  <p style="font-weight:bold;">📈 Axes Description</p>
#  <ul style="margin-left:15px;">
#             <li><b>X-axis:</b> Time (h) – cumulative operating hours.</li>
#             <li><b>Y-axis:</b> Stack Voltage (V) – measured output voltage of the PEMFC stack.</li>
#   </ul>
#  <p style="font-weight:bold;">🔍 Key Observations</p>
#   <ul style="margin-left:15px;">
#             <li>Short-term volatility captures fluctuations, load cycles, and operational spikes/dips.</li>
#             <li>Gradual long-term drift indicates underlying stack degradation.</li>
#             <li>Stable mean voltage with minimal fluctuation reflects consistent stack performance.</li>
#             <li>High voltage volatility may signal thermal management issues, reactant flow instability, or sensor/control anomalies.</li>
#         </ul>
#
#  <p style="font-weight:bold;">⚙️ Practical Implications</p>
#         <ul style="margin-left:15px;">
#             <li>Monitors PEMFC operational stability in real time.</li>
#             <li>Provides early warning of performance issues before significant degradation occurs.</li>
#             <li>Supports maintenance planning and operational optimization.</li>
#         </ul>
#
# <p style="font-weight:bold;">🧩 Summary</p>
#    <p>
#             This visualization quantifies both short-term variability and long-term trends in PEMFC stack voltage, offering insights into system reliability, control effectiveness, and early degradation signals for health monitoring and prognostics.
#    </p>
#
# </div>
# </div>

# %% [markdown]
# ## Rolling or lag features for time-series ML

# %%
roll_mean = df['stack voltage (V)'].rolling(window=5).mean()
roll_std = df['stack voltage (V)'].rolling(window=5).std()

# %%
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(df['stack voltage (V)'], color='blue',label='PEMFC STACKING')
ax.plot(roll_mean, color='red', label='Rolling stack voltage (V) Mean')
ax.plot(roll_std, color='black', label='Rolling stack voltage (V) Standard Deviation')
ax.legend()
fig.tight_layout()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> Models</p>
# </div>

# %% [markdown]
# # ================================
# # Time series
#
# # ================================

# %%
df = df.sort_values("Time (h)")
df = df.set_index("Time (h)")

# %%
df["stack_voltage_smooth"] = savgol_filter(df["stack voltage (V)"], 51, 3)

# %%
df["stack_voltage_smooth"].plot(figsize=(12,5), title="Stack Voltage Degradation")
# Out:
# <Axes: title={'center': 'Stack Voltage Degradation'}, xlabel='Time (h)'>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000; text-align: justify; color: black; font-size: 14px; padding: 10px; background:#F2FFFF;">
#   <p style="background:#E6FFFA; padding:8px; border-left:4px solid #008000;">
#         The <strong>stack_voltage_smooth</strong> column is generated by applying a Savitzky-Golay filter to the raw stack voltage (<em>stack voltage (V)</em>), which prepares the data for RUL forecasting, plotting, and ML modeling.
#   </p>
#
#   <p style="background:#E6FFFA; padding:8px; border-left:4px solid #008000;">
#         <strong>Window Length:</strong> 51 samples are used to fit the polynomial. The window must be odd. A larger window smooths more but responds slower to changes. For PEMFC degradation, 51 is suitable for hourly or few-minute data.
#    </p>
#
#    <p style="background:#E6FFFA; padding:8px; border-left:4px solid #008000;">
#         <strong>Polynomial Order:</strong> 3 is commonly used to capture trends without distorting the degradation slope. Higher order fits local curvature better but may overfit noise.
#    </p>
#
#    <p style="background:#E6FFFA; padding:8px; border-left:4px solid #008000;">
#         <strong>Result:</strong> <strong>stack_voltage_smooth</strong> now preserves the long-term degradation trend while removing high-frequency noise, ready for RUL estimation, trend visualization, and machine learning modeling.
#     </p>
# </div>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Check for stationarity by Adfuller
# </center></p></h1>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000;
#             text-align: justify; color: black; font-size: 14px;
#             padding: 10px; background:#F2FFFF;">
#
#   <h2>📈 Stationarity</h2>
#
#   <p>
#     <b>In time series analysis, stationarity refers to a property of a series where its statistical properties
#     (like mean, variance, and autocorrelation) are constant over time.</b>
#   </p>
#
#   <p>
#     Stationarity plays a vital role in time series analysis. When we grasp this concept, we gain insights into
#     which methods are suitable for our data and how we can enhance forecast accuracy. By converting non-stationary
#     data, we can apply various statistical tools to understand and predict time series behavior.
#   </p>
#
#   <p>
#     Imagine you're trying to predict the weather. Stationarity is like having consistent weather patterns.
#     If it's usually sunny in summer and rainy in winter, that's stationary. But if the weather goes crazy with
#     random heat waves and snowstorms, that's non-stationary.
#   </p>
#
#   <p>
#     Many forecasting tools work best with consistent patterns. By smoothing out wild swings in your data
#     (making the “crazy weather” more predictable), you can make better forecasts for your time series.
#   </p>
#
#   <p style="text-align:center;">
#     <img src="https://miro.medium.com/v2/resize:fit:1147/1*xdblkZyg6YmmReAkZHUksw.png"
#          alt="stationarity" style="max-width:100%; height:auto; border-radius:5px;">
#   </p>
#
#   <h3>🔹 Intuitive Explanation</h3>
#   <p>
#     Imagine a time series like a river flowing at a constant rate. The average water level (mean) stays the same,
#     and the fluctuations around that average (variance) are consistent throughout the river's course.
#     This is a stationary series.
#   </p>
#   <p>
#     In contrast, a non-stationary series would be like a river with changing water levels — flooding seasonally
#     or drying up over time. The mean and variability change depending on the season or long-term trends.
#   </p>
#
#   <h3>🔹 Formal Definition</h3>
#   <p>A time series is stationary if:</p>
#   <ul>
#     <li><b>Mean is constant:</b> The average value of the series does not trend upward or downward.</li>
#     <li><b>Variance is constant:</b> The spread of the data points around the mean remains consistent.</li>
#     <li><b>Autocorrelation is constant:</b> Relationships between observations at different lags do not change over time.</li>
#   </ul>
#
#   <h3>🔹 Why Stationarity Matters</h3>
#   <p>
#     Many statistical methods for time series forecasting assume stationarity. Non-stationary data may produce unreliable results:
#   </p>
#   <ul>
#     <li><b>Forecasting:</b> Predicting future values is difficult if patterns change over time.</li>
#     <li><b>Statistical Tests:</b> Validity of tests often relies on stationary data.</li>
#   </ul>
#
#   <h3>🔹 Transforming Non-Stationary Data</h3>
#   <p>Common techniques to make a series stationary include:</p>
#   <ul>
#     <li><b>Differencing:</b> Subtracting a previous value from the current value to remove trends.</li>
#     <li><b>Detrending:</b> Fitting a trend line and subtracting it from the series to remove long-term trends.</li>
#     <li><b>Seasonal Adjustment:</b> Seasonal differencing or adjustments remove seasonal patterns.</li>
#   </ul>
#
# </div>

# %%
sample_series = df['stack voltage (V)'].sample(frac=0.2, random_state=42)
adf_result = adfuller(sample_series)
print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
# Out:
# ADF Statistic: -167.61399551747203
# p-value: 0.0

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000;
# text-align: justify; color: black; font-size: 14px; padding: 12px; background:#F2FFFF;">
#
#   <p style="font-size: 14px; color: green; font-weight: bold;">
#       📊 Augmented Dickey-Fuller (ADF) Test
#   </p>
#
#   <p>
#       The <strong>Augmented Dickey-Fuller (ADF) test</strong> is a statistical test used to determine whether a time series is
#       <strong>stationary or non-stationary</strong>. Stationarity is extremely important in many time series models such as ARIMA.
#   </p>
#
#   <p>
#      The ADF test evaluates the <strong>null hypothesis</strong> that the time series contains a <em>unit root</em>, meaning
#      that it is <strong>non-stationary</strong>. The alternative hypothesis suggests the series <strong>is stationary</strong>.
#   </p>
#
#   <p>
#      When running the ADF test, two values are mainly interpreted:
#   </p>
#
#   <ul style="font-family: cursive; font-size: 14px;">
#       <li><strong>ADF Statistic</strong> – negative value, the more negative → stronger evidence of stationarity</li>
#       <li><strong>p-value</strong> – if below <strong>0.05</strong>, reject the null hypothesis</li>
#   </ul>
#
#   <p>
#      A low p-value indicates strong evidence against the presence of a unit root and therefore supports that
#      the <strong>time series is stationary</strong>.
#   </p>
#
#   <p style="font-size: 14px; color: green; font-weight: bold;">
#       ✔ Key Insights
#   </p>
#
#   <ul style="font-family: cursive; font-size: 14px;">
#       <li>Time series <strong>must be stationary</strong> before applying ARIMA</li>
#       <li><strong>AIC optimization</strong> helps select the best ARIMA parameters</li>
#       <li>ARIMA is effective for data with <strong>trend</strong> and <strong>seasonality</strong></li>
#   </ul>
#
# </div>

# %% [markdown]
# #  Saving

# %%
# Example: save your DataFrame (replace df5 with your actual DataFrame)
df.to_csv('stack_voltage_smooth.csv', index=False)

# %%
from google.colab import files
files.download('stack_voltage_smooth.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')

# Save to your Google Drive
df.to_csv('/content/drive/MyDrive/stack_voltage_smooth.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> SPLIT(train/validation/test) + SCALING (ARIMA, SARIMA)</p>
# </div>

# %%
target = "stack_voltage_smooth"

# %%
y_train = train[target]
y_val   = val[target]
y_test  = test[target]

# %%
# Print shapes for verification
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_val: {y_val.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of y_train: (77795,)
# Shape of y_val: (23842,)
# Shape of y_test: (42225,)

# %% [markdown]
# <center><img src="https://static.wixstatic.com/media/24bff7_74439e8fe4c74187af5bcf365cf9eeb2~mv2.png/v1/fill/w_740,h_486,al_c,q_85,usm_0.66_1.00_0.01,enc_auto/24bff7_74439e8fe4c74187af5bcf365cf9eeb2~mv2.png"
# width="70%" height="70%" />

# %% [markdown]
# # ================================
# # ARIMA
# ### statistical model for time series and forcasting
#
# # ================================

# %% [markdown]
# ![](https://predictivehacks.com/wp-content/uploads/2021/04/arimaschema-1024x554.png)

# %% [markdown]
# <div style="border-radius: 6px; border: 3px solid #008000;
#             padding: 14px; background: #F2FFFF;
#             font-family: cursive; font-size: 14px;
#             color: black; text-align: justify;">
#
#   <h2 style="color: green; font-size: 18px;">
#     ARIMA: A Time Machine for Predictions
#   </h2>
#
#   <p>
#     <strong>ARIMA</strong>, standing for <strong>Autoregressive Integrated Moving Average</strong>,
#     is a statistical model that empowers you to forecast future values based on past observations
#     in a time series dataset. It is widely used for analyzing and predicting trends in various
#     fields, from <strong>finance</strong> (stock prices) to <strong>weather forecasting</strong>
#     (temperature variations).
#   </p>
#
#   <h2 style="color: green; font-size: 16px;">
#     The Building Blocks of ARIMA
#   </h2>
#
#   <p>
#     ARIMA decomposes a time series into three fundamental components:
#   </p>
#
#   <ol>
#     <li>
#       <strong>Autoregressive (AR):</strong>
#       Captures the influence of past values on the current observation.
#       For example, when predicting tomorrow’s stock price, ARIMA considers prices from previous
#       days up to order <strong>p</strong>.
#     </li>
#
#    <li>
#       <strong>Integrated (I):</strong>
#       Handles non-stationarity in the data.
#       Differencing removes trends by subtracting the previous value from the current value,
#       applied up to order <strong>d</strong>.
#     </li>
#
#   <li>
#       <strong>Moving Average (MA):</strong>
#       Models the influence of past forecast errors on current predictions.
#       The parameter <strong>q</strong> specifies how many past errors are considered.
#     </li>
#   </ol>
#
#   <h2 style="color: green; font-size: 16px;">
#     Understanding the Notation
#   </h2>
#
#   <p>
#     ARIMA models are represented as <strong>ARIMA(p, d, q)</strong>, where:
#   </p>
#
#   <ul>
#     <li><strong>p</strong> – number of autoregressive terms</li>
#     <li><strong>d</strong> – degree of differencing required for stationarity</li>
#     <li><strong>q</strong> – number of moving average terms</li>
#   </ul>
#
#   <h1 style="color: green; font-size: 17px;">
#     Example: Predicting Sales Figures
#   </h1>
#
#   <p>
#     Suppose a business analyst wants to forecast monthly sales using historical data.
#     An ARIMA model can capture both trends and short-term dependencies.
#   </p>
#
#   <ul>
#     <li>
#       <strong>ARIMA(2, 1, 1):</strong>
#       Uses the past two months’ sales (<strong>p = 2</strong>),
#       applies one differencing step to remove trends (<strong>d = 1</strong>),
#       and incorporates the previous forecast error (<strong>q = 1</strong>).
#     </li>
#   </ul>
#
#   <h2 style="color: green; font-size: 16px;">
#     Strengths of ARIMA
#   </h2>
#
#   <ol>
#     <li><strong>Effective for Stationary Data:</strong> Performs exceptionally well wh

# %%
p = 2    # Auto Regressive (AR) , look at relation between current values and previous values(lags)
d = 1    # Integrated , which times of differnces (first differencing , second , third etc) can use to make stationary  Xt=Xt-Xt-1
q = 2    # Moving Average , make model relation between current vale and error terms (forcast error)


# work with historical data and simple but is not accurate model and predict for short term

# %%
# Fit the ARIMA model
y_train_val = pd.concat([y_train, y_val])

arima_model_final = ARIMA(y_train_val, order=(2, 1, 2))
arima_fit_final = arima_model_final.fit()


# Print the model summary
print(model_fit.summary())


# Plot diagnostic plots
model_fit.plot_diagnostics(figsize=(25,10))
plt.show()
# Out:
#                                 SARIMAX Results
# ...
# Dep. Variable:     stack_voltage_smooth   No. Observations:                77795
# Model:                   ARIMA(2, 1, 2)   Log Likelihood              592380.131
# Date:                  Thu, 15 Jan 2026   AIC                       -1184750.262
# Time:                          04:14:57   BIC                       -1184703.953
# Sample:                               0   HQIC                      -1184736.048
#                                 - 77795
# Covariance Type:                    opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0006      0.001     -0.552      0.581      -0.003       0.002
# ar.L2          0.8073      0.001    736.327      0.000       0.805       0.809
# ma.L1          0.1320      0.001    150.817      0.000       0.130       0.134
# ...

# %% [markdown]
# <h3 style="color: green;">Diagnostic Summary</h3>
#
# <ul>
#   <li><b>Mean behavior:</b> Well captured, with residuals centered around zero.</li>
#   <li><b>Normality:</b> Largely satisfied, though mild heavy-tailed behavior is observed.</li>
#   <li><b>Autocorrelation:</b> Residual ACF/PACF reveal remaining dependence, indicating incomplete error modeling.</li>
#   <li><b>Variance:</b> Clear heteroskedasticity suggests time-varying volatility.</li>
#   <li><b>Model fit:</b> Extremely close fitted values raise concerns of potential overfitting.</li>
# </ul>
#
# <b>Conclusion:</b> While the ARIMA model accurately captures the central trend, it fails to fully satisfy residual assumptions, motivating model simplification and explicit volatility modeling (e.g., ARIMA–GARCH) for robust forecasting.

# %%
# Make predictions on the test set
test_steps = len(y_test)
y_test_pred = arima_fit_final.forecast(steps=test_steps)

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_test_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

print(f"ARIMA Test MAE:  {mae:.6f}")
print(f"ARIMA Test RMSE: {rmse:.6f}")
# Out:
# ARIMA Test MAE:  0.011217
# ARIMA Test RMSE: 0.013426

# %%
residuals = arima_fit_final.resid
plt.figure(figsize=(12,4))
plt.plot(residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals of ARIMAX")
plt.show()

# Histogram
residuals.hist(bins=50)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label="True")
plt.plot(y_test.index, y_test_pred, label="ARIMA Forecast")
plt.xlabel("Time h")
plt.ylabel("Stack Voltage")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000; text-align: justify; color: black; font-size: 14px; padding: 15px; background:#F2FFFF;">
#
#   <p style="font-size: 16px; color: green; font-weight: bold; text-align:center;">
#         📊 ARIMA Model Performance: IT_solar_generation
#     </p>
#
#   <p>
#         The <strong>Root Mean Squared Error (RMSE)</strong> for the ARIMA model on <strong>'IT_solar_generation'</strong> is approximately
#         <span style="color:red; font-weight:bold;">2486</span>. As with the 'IT_load_new' model, this RMSE value indicates how accurately the model predicts the response.
#     </p>
#
#   <p style="color:green; font-weight:bold;">📌 Interpretation</p>
#     <ul>
#         <li>The RMSE shows the average deviation between predicted and actual solar generation values.</li>
#         <li>A lower RMSE indicates better prediction accuracy, but it is always useful to compare it with the data scale or other models.</li>
#         <li>Visual inspection is also crucial to understand how well the model captures trends and patterns.</li>
#     </ul>
#
#   <p style="color:green; font-weight:bold;">📈 Visual Comparison</p>
#     <p>
#         The plot below shows the <strong>actual versus predicted solar generation</strong> values for the test set.
#         Similar to the load model, the ARIMA model captures the general pattern of the time series data, although some differences remain.
#     </p>
#
#  <div style="text-align:center; padding:10px;">
#         <img src="YOUR_SOLAR_PLOT_IMAGE.png" style="width:90%; border-radius:10px; border:2px solid #008000;">
#         <p style="font-size:12px; color:#555;">(Replace this image with your actual vs predicted plot for IT_solar_generation)</p>
#     </div>
#
# </div>

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> ACF & PACF Plots</p>
# </div>

# %%
# --------------------------------------
#  First difference the training target
# --------------------------------------
y_train_diff = y_train.diff().dropna()

# --------------------------------------
#  Plot ACF and PACF
# --------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

plot_acf(
    y_train_diff,
    lags=50,
    ax=axes[0]
)
axes[0].set_title("ACF of Differenced Stack Voltage")

plot_pacf(
    y_train_diff,
    lags=50,
    ax=axes[1],
    method="ywm"
)
axes[1].set_title("PACF of Differenced Stack Voltage")

plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> auto_arima </p>
# </div>

# %%
# -------------------------------------------------
#  Fit Auto-ARIMA on training data
# -------------------------------------------------
auto_model = auto_arima(
    y_train,
    start_p=0, start_q=0,
    max_p=4, max_q=4,
    d=None,                 # let auto_arima decide differencing
    seasonal=False,
    trace=True,
    stepwise=True,
    suppress_warnings=True
)

# -------------------------------------------------
#  Model summary
# -------------------------------------------------
print(auto_model.summary())

# -------------------------------------------------
#  Forecast on test set
# -------------------------------------------------
y_test_pred1 = auto_model.predict(n_periods=len(y_test))

# -------------------------------------------------
#  Evaluate performance
# -------------------------------------------------
rmse_auto = sqrt(mean_squared_error(y_test, y_test_pred1))
mae_auto  = mean_absolute_error(y_test, y_test_pred1)

print(f"Auto-ARIMA Test MAE : {mae_auto:.6f}")
print(f"Auto-ARIMA Test RMSE: {rmse_auto:.6f}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1178869.619, Time=29.34 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1181604.060, Time=22.20 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1181026.108, Time=64.89 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1178868.598, Time=5.75 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-1183007.662, Time=30.15 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-1183765.179, Time=37.38 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-1184203.929, Time=47.30 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-1184158.899, Time=53.97 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-1183698.731, Time=44.19 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=-1184188.763, Time=51.45 sec
#
# Best model:  ARIMA(4,1,0)(0,0,0)[0] intercept
# Total fit time: 386.644 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                77795
# ...

# %% [markdown]
# # ================================
# # SARIMA
#
# # ================================

# %% [markdown]
# <div style="border-radius: 6px; font-family: cursive; border: 3px solid #009614ff;
#             text-align: justify; color: black; font-size: 14px;
#             padding: 12px; background:#F2F9FF;">
#
#   <p style="text-align: center; font-size: 16px; color: #00962dff; font-weight: bold;">
#     ## SARIMA for Time Series Forecasting
#   </p>
#
#   <p>
#     <strong>In the realm of time series analysis, predicting future values from past observations is a constant pursuit.</strong>
#     SARIMA (<strong>Seasonal Autoregressive Integrated Moving Average</strong>) emerges as a powerful tool for this task,
#     particularly for data exhibiting <strong>seasonality</strong>.
#   </p>
#
#   <p style="color:#005B96; font-weight:bold;">
#     ## What is SARIMA?
#   </p>
#
#   <p>
#     <strong>SARIMA</strong> is a statistical model that extends <strong>ARIMA</strong> by incorporating
#     <strong>seasonal components</strong>. It leverages:
#   </p>
#
#   <ul>
#     <li>Past observations (AR)</li>
#     <li>Differencing to achieve stationarity (I)</li>
#     <li>Past forecast errors (MA)</li>
#     <li>Seasonal AR, seasonal differencing, and seasonal MA</li>
#   </ul>
#
#   <p style="color:#005B96; font-weight:bold;">
#     ## Key Components of SARIMA
#   </p>
#
#   <ul>
#     <li><strong>Non-seasonal AR (p):</strong> Influence of recent past values</li>
#     <li><strong>Differencing (d):</strong> Removes long-term trends</li>
#     <li><strong>Non-seasonal MA (q):</strong> Captures short-term forecast errors</li>
#     <li><strong>Seasonal AR (P):</strong> Influence of past seasonal values</li>
#     <li><strong>Seasonal Differencing (D):</strong> Removes seasonal trends</li>
#     <li><strong>Seasonal MA (Q):</strong> Seasonal forecast error correction</li>
#     <li><strong>Seasonality (s):</strong> Number of periods in one season (e.g., 24 for hourly daily seasonality)</li>
#   </ul>
#
#   <p style="color:#005B96; font-weight:bold;">
#     # Example: Predicting Electricity Prices
#   </p>
#
#   <p>
#     Electricity prices often exhibit <strong>strong seasonal behavior</strong>
#     due to heating, cooling, and industrial demand.
#     SARIMA is particularly suitable for such patterns.
#   </p>
#
#   <p>
#     <strong>Example configuration:</strong>
#   </p>
#
#   <ul>
#     <li>p = 2 → influence of last 2 price points</li>
#     <li>d = 1 → remove long-term trend</li>
#     <li>q = 1 → account for previous forecast error</li>
#     <li>P = 1 → seasonal autoregression</li>
#     <li>D = 1 → seasonal differencing</li>
#     <li>s = 12 → monthly seasonality</li>
#   </ul>
#
#   <p>
#     By fitting a SARIMA model with these parameters, future electricity prices
#     can be forecasted more accurately than standard ARIMA.
#   </p>
#
#   <p style="color:#005B96; font-weight:bold;">
#     ## Benefits of SARIMA
#   </p>
#
#   <ul>
#     <li><strong>Excellent for seasonal data</strong></li>
#     <li><strong>Interpretable statistical structure</strong></li>
#     <li><strong>Strong diagnostic capabilities</strong></li>
#   </ul>
#
#   <p style="color:#005B96; font-weight:bold;">
#     ## Limitations of SARIMA
#   </p>
#
#   <ul>
#     <li>Requires stationarity</li>
#     <li>Hyperparameter tuning can be complex</li>
#     <li>Limited performance for highly non-linear patterns</li>
#   </ul>
#
#   <p>
#     <strong>Conclusion:</strong><br>
#     SARIMA remains a <strong>robust and interpretable model</strong> for seasonal time series forecasting,
#     particularly in energy markets where demand and price patterns repeat over time.
#   </p>
#
# </div>

# %%
#
# Concatenate train + validation
y_train_val = pd.concat([y_train, y_val])

#  Define SARIMA orders
sarima_order = (1, 1, 1)                # (p,d,q)
# For PEMFC data, likely no monthly seasonality. Use seasonal_order = (0,0,0,0)
seasonal_order = (0, 0, 0, 0)          # No seasonal component

#  Fit SARIMAX model
sarimax_model = SARIMAX(
    y_train_val,
    order=sarima_order,
    seasonal_order=seasonal_order,
    enforce_stationarity=False,
    enforce_invertibility=False
)

sarimax_res = sarimax_model.fit()
print(sarimax_res.summary())

# Plot diagnostic plots
sarimax_res.plot_diagnostics(figsize=(20, 10))
plt.show()
# Out:
#                                 SARIMAX Results
# ...
# Dep. Variable:     stack_voltage_smooth   No. Observations:               101637
# Model:                 SARIMAX(1, 1, 1)   Log Likelihood              773395.708
# Date:                  Thu, 15 Jan 2026   AIC                       -1546785.416
# Time:                          05:21:59   BIC                       -1546756.829
# Sample:                               0   HQIC                      -1546776.747
#                                - 101637
# Covariance Type:                    opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8734      0.001    732.370      0.000       0.871       0.876
# ma.L1         -0.7280      0.001  -1349.610      0.000      -0.729      -0.727
# sigma2      1.382e-08   6.21e-11    222.582      0.000    1.37e-08    1.39e-08
# ...

# %% [markdown]
# <div style="border-radius: 6px; font-family: cursive; border: 3px solid #009614ff;
#             text-align: justify; color: black; font-size: 14px;
#             padding: 12px; background:#F2F9FF;">
#
#   <p style="text-align: center; font-size: 16px; color: #00962dff; font-weight: bold;">
#     SARIMAX(1,1,1) Results – PEMFC Stack Voltage
#   </p>
#
#   <p>
#     The SARIMAX model captures the <b>overall downward trend</b> of the stack voltage effectively.
#     The AR(1) coefficient of <b>0.873</b> highlights the strong memory effect,
#     while the negative MA(1) coefficient of <b>-0.728</b> smooths short-term fluctuations.
#   </p>
#
#   <p>
#     Residual diagnostics show near-normal distribution, but some <b>autocorrelation</b>
#     and <b>heteroskedasticity</b> remain, reflecting transient voltage variations and
#     nonlinear electrochemical behaviors not captured by the linear model.
#   </p>
#
#   <p>
#     In practice, SARIMAX provides a <b>reliable baseline for trend forecasting</b>
#     and RUL estimation, but additional modeling may be needed for precise short-term dynamics.
#   </p>
# </div>

# %%
residuals = sarimax_res.resid  # use fitted results, not the model

plt.figure(figsize=(14, 5))
plt.plot(residuals, label='Residuals')
plt.axhline(0, color='red', linestyle='--')
plt.title('SARIMAX Residuals')
plt.xlabel('Date')
plt.ylabel('Residual')
plt.legend()
plt.show()

# Histogram + KDE
plt.figure(figsize=(10,5))
plt.hist(residuals, bins=30, density=True, alpha=0.6, color='skyblue')
residuals.plot(kind='kde', color='red')
plt.title('Residuals Histogram + Density')
plt.show()

# %%
# Generate forecast with confidence intervals
forecast_res = sarimax_res.get_forecast(steps=len(y_test))

# Predicted mean
y_test_pred = forecast_res.predicted_mean

# 95% Confidence intervals
conf_int = forecast_res.conf_int()

# Show the first few rows
print(conf_int.head())
# Out:
#         lower stack_voltage_smooth  upper stack_voltage_smooth
# 101637                    3.231525                    3.231995
# 101638                    3.231338                    3.232059
# 101639                    3.231172                    3.232117
# 101640                    3.231020                    3.232175
# 101641                    3.230879                    3.232234

# %%
#  Evaluate performance
rmse1 = sqrt(mean_squared_error(y_test, y_test_pred))
mae1 = mean_absolute_error(y_test, y_test_pred)

print(f"SARIMAX Test MAE: {mae1:.6f}")
print(f"SARIMAX Test RMSE: {rmse1:.6f}")
# Out:
# SARIMAX Test MAE: 0.011235
# SARIMAX Test RMSE: 0.013449

# %%
#  Plot forecast vs actual
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label="Actual")
plt.plot(y_test.index, y_test_pred, label="SARIMAX Forecast", linestyle="--")
plt.xlabel("Time index")
plt.ylabel("Stack Voltage")
plt.title("SARIMAX Forecast vs Actual")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label="Actual")
plt.plot(y_test.index, y_test_pred, label="SARIMAX Forecast", linestyle="--")
plt.fill_between(y_test.index,
                  conf_int.iloc[:, 0],  # lower CI
                 conf_int.iloc[:, 1],  # upper CI
                 color='pink', alpha=0.3, label="95% CI")
plt.xlabel("Time index")
plt.ylabel("Stack Voltage")
plt.title("SARIMAX Forecast with 95% Confidence Interval")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius: 6px; font-family: cursive; border: 3px solid #009614ff;
#             text-align: justify; color: black; font-size: 14px;
#             padding: 12px; background:#F2F9FF;">
#
#   <p style="text-align: center; font-size: 16px; color: #00962dff; font-weight: bold;">
#     SARIMAX Forecast Overview – PEMFC Stack Voltage
#   </p>
#
#   <p>
#     The plot shows the <b>actual stack voltage</b> (green), the <b>SARIMAX forecast</b> (red dashed line),
#     and the <b>95% confidence interval</b> (pink shaded area). Over the 350 test points, the model
#     successfully captures the <b>overall downward degradation trend</b> of the stack voltage.
#   </p>
#
#   <p>
#     Most actual values lie within the confidence bounds, indicating reasonable uncertainty quantification.
#     The CI widens slightly over time, reflecting increasing prediction uncertainty as the forecast horizon extends.
#     Short-term fluctuations are less accurately tracked, consistent with the residual heteroskedasticity observed
#     in previous diagnostics.
#   </p>
#
#   <p>
#     <b>Key insights:</b> The forecast provides a reliable trend indicator for RUL estimation and maintenance planning,
#     while occasional deviations highlight periods where nonlinear dynamics or rapid degradation are not fully captured.
#     Overall, the model offers a practical baseline for predictive monitoring of fuel cell stack performance.
#   </p>
# </div>

# %% [markdown]
# # ================================
# # Prophet
# # ================================

# %%
# Prepare data
df_prophet = y_train_val.reset_index()  # assuming your index is datetime or sequential
df_prophet = df_prophet.rename(columns={'Time (h)': 'ds', 'stack_voltage_smooth': 'y'})

# %%
print(df_prophet.head())
print(df_prophet.columns)
# Out:
#    Time (h)         y
# 0  0.000000  3.317816
# 1  0.000156  3.317496
# 2  0.000321  3.317192
# 3  0.000475  3.316904
# 4  0.000624  3.316632
# Index(['Time (h)', 'y'], dtype='object')

# %%
# Initialize and fit model
model = Prophet(
    daily_seasonality=False,   # no strong daily pattern
    yearly_seasonality=False,  # no yearly cycle
    weekly_seasonality=False,  # no weekly cycle
    changepoint_prior_scale=0.05,# controls flexibility of trend
    interval_width=0.95
)
model.fit(df_prophet)

# %%
# Forecast horizon = length of test set
future_periods = len(y_test)
future = model.make_future_dataframe(periods=future_periods, freq='H')  # hourly data

# %%
# Prepare future dataframe
future1 = pd.DataFrame({'ds': y_test.index})  # make sure index matches datetime or numeric


# Forecast
forecast = model.predict(future)

#  Plot forecast with Prophet
fig1 = model.plot(forecast)
plt.title('Prophet Forecast – PEMFC Stack Voltage', fontsize=16, weight='bold')
plt.xlabel('Time')
plt.ylabel('Stack Voltage')
plt.show()

#  Plot components (trend, seasonality)
fig2 = model.plot_components(forecast)
plt.show()

# %%
y_test_forecast = forecast['yhat'].iloc[len(y_train_val):].values  # only test period

rmse2 = sqrt(mean_squared_error(y_test, y_test_pred))
mae2 = mean_absolute_error(y_test, y_test_pred)

print(f"Prophet Test MAE: {mae2:.6f}")
print(f"Prophet Test RMSE: {rmse2:.6f}")
# Out:
# Prophet Test MAE: 0.011235
# Prophet Test RMSE: 0.013449

# %% [markdown]
# # ================================
# #  Recurrent Neural Network (RNN)
# # ================================

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Sequence Models and RNN/LSTM</title>
# </head>
# <body>
#
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000;
#             text-align: justify; color: black; font-size: 14px; padding: 15px;
#             background:#F2FFFF;"
#
# <a id="rnn"></a>
#     <h2>Recurrent Neural Network (RNN)</h2>
#     <ul>
#         <li>RNNs can remember important information from previous inputs.</li>
#         <li>The output is fed forward AND back into the RNN → due to internal memory.</li>
#         <li>RNN has a temporal loop that allows self-feedback.</li>
#         <li>RNNs have short-term memory: they remember previous time steps.</li>
#         <li>This memory helps the network make better predictions based on past data.</li>
#     </ul>
#
# <h3>Problems in RNNs</h3>
#     <ul>
#         <li><strong>Exploding Gradients:</strong> Gradients become too large → unstable training.</li>
#         <li><strong>Vanishing Gradients:</strong> Gradients become too small → very slow learning.</li>
#     </ul>
#
#  <p>
#         <strong>Gradient:</strong> Controls how weights change during training based on the loss function.
#     </p>
#
# </div>
#
# </body>
# </html>

# %% [markdown]
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Network_framework.gif)

# %% [markdown]
# # Prepare Dataset and Split and convert- without validation

# %% [markdown]
# # Split (train/test/validation real)

# %%
target = "stack_voltage_smooth"
features = [
    "current density (A/cm²)",
    "stack current (A)",
    "hydrogen inlet temperature (°C)",
    "hydrogen inlet flow rate (L/min)",
    "air inlet flow rate (L/min)",
    "PinH2 (mbara)",
    "PoutH2 (mbara)",
    "PinAIR (mbara)",
    "PoutAIR (mbara)",
    "DWAT (l/mn)"
]

# %%
#  Split data
train = df[df.index <= 600]
val   = df[(df.index > 600) & (df.index <= 800)]
test  = df[df.index > 800]

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train = scaler_X.fit_transform(train[features])
X_val   = scaler_X.transform(val[features])
X_test  = scaler_X.transform(test[features])

y_train = scaler_y.fit_transform(train[[target]])
y_val   = scaler_y.transform(val[[target]])
y_test  = scaler_y.transform(test[[target]])

# %%
sequence_length = 10

# %%
def create_sequences(X, y, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i+seq_length])
        y_seq.append(y[i+seq_length])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, y_train, sequence_length)
X_val_seq, y_val_seq     = create_sequences(X_val, y_val, sequence_length)
X_test_seq, y_test_seq   = create_sequences(X_test, y_test, sequence_length)

# %%
 if X_train_seq.shape[2] == 1:
    X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], 1))
    X_val_seq   = X_val_seq.reshape((X_val_seq.shape[0], X_val_seq.shape[1], 1))
    X_test_seq  = X_test_seq.reshape((X_test_seq.shape[0], X_test_seq.shape[1], 1))

print("Train shape:", X_train_seq.shape, y_train_seq.shape)
print("Validation shape:", X_val_seq.shape, y_val_seq.shape)
print("Test shape:", X_test_seq.shape, y_test_seq.shape)
# Out:
# Train shape: (77785, 10, 10) (77785, 1)
# Validation shape: (23832, 10, 10) (23832, 1)
# Test shape: (42215, 10, 10) (42215, 1)

# %%
plt.figure(figsize=(14, 5))

# Plot full signal
plt.plot(df.index, df[target], label='stack_voltage_smooth', linewidth=1)

# Split lines
plt.axvline(x=600, linestyle='--', linewidth=2, color="red", label='Train / Validation split')
plt.axvline(x=800, linestyle='--', linewidth=2, color="black", label='Validation / Test split')

# Labels
plt.xlabel('Time index')
plt.ylabel('stack_voltage_smooth')
plt.title('PEMFC Voltage Time Series with Train / Validation / Test Split')
plt.legend()


plt.show()

# %%
rnn_model = Sequential()
rnn_model.add(SimpleRNN(
    units=64,
    input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])   # (timesteps, features)
))
rnn_model.add(Dense(1))


rnn_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

# %%
early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# %%
history_rnn = rnn_model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
rnn_model.summary()
# Out:
# Epoch 1/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0423 - mae: 0.1588 - val_loss: 0.1398 - val_mae: 0.3536
# Epoch 2/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0176 - mae: 0.0992 - val_loss: 0.1399 - val_mae: 0.3521
# Epoch 3/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0153 - mae: 0.0911 - val_loss: 0.1279 - val_mae: 0.3267
# Epoch 4/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0142 - mae: 0.0869 - val_loss: 0.1530 - val_mae: 0.3533
# Epoch 5/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0134 - mae: 0.0840 - val_loss: 0.1680 - val_mae: 0.3937
# Epoch 6/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0133 - mae: 0.0843 - val_loss: 0.1866 - val_mae: 0.4082
# Epoch 7/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0132 - mae: 0.0825 - val_loss: 0.1547 - val_mae: 0.3629
# Epoch 8/100
# ...

# %%
# --- Predict ---
train_predict = rnn_model.predict(X_train_seq)
test_predict  = rnn_model.predict(X_test_seq)

train_predict_inv = scaler_y.inverse_transform(train_predict)
test_predict_inv  = scaler_y.inverse_transform(test_predict)

y_train_inv = scaler_y.inverse_transform(y_train_seq.reshape(-1,1))
y_test_inv  = scaler_y.inverse_transform(y_test_seq.reshape(-1,1))
# Out:
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1320/1320 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
# ---Evaluation----
train_mae_rnn  = mean_absolute_error(y_train_inv, train_predict_inv)
train_rmse_rnn = np.sqrt(mean_squared_error(y_train_inv, train_predict_inv))

test_mae_rnn  = mean_absolute_error(y_test_inv, test_predict_inv)
test_rmse_rnn = np.sqrt(mean_squared_error(y_test_inv, test_predict_inv))

print(f"Train MAE  : {train_mae_rnn:.4f}")
print(f"Train RMSE : {train_rmse_rnn:.4f}")
print(f"Test MAE   : {test_mae_rnn:.4f}")
print(f"Test RMSE  : {test_rmse_rnn:.4f}")
# Out:
# Train MAE  : 0.0080
# Train RMSE : 0.0111
# Test MAE   : 0.0394
# Test RMSE  : 0.0431

# %%
rnn_df1 = pd.DataFrame(history_rnn.history)
rnn_df1.head()
# Out:
#        loss       mae  val_loss   val_mae
# 0  0.028677  0.128324  0.139797  0.353629
# 1  0.016597  0.096000  0.139916  0.352146
# 2  0.014884  0.089727  0.127871  0.326683
# 3  0.014319  0.087095  0.152999  0.353336
# 4  0.013689  0.084923  0.168022  0.393671

# %%
Rnn_df = pd.DataFrame({
    "train_mae": [train_mae_rnn],
    "train_rmse": [train_rmse_rnn],
    "test_mae": [test_mae_rnn],
    "test_rmse": [test_rmse_rnn]
})

Rnn_df.head()
# Out:
#    train_mae  train_rmse  test_mae  test_rmse
# 0   0.008009    0.011086  0.039364   0.043125

# %%
plt.figure(figsize=(20, 5))
plt.plot(history_rnn.history['loss'], label='Train Loss', color='blue')
plt.plot(history_rnn.history['val_loss'], label='Validation Loss', color='red')
plt.title('Model Loss Over Epochs', fontsize=16, fontweight='bold')
plt.ylabel('Loss', fontsize=14)
plt.xlabel('Epochs', fontsize=14)
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(history_rnn.history['mae'], 'g-', label='Training MAE')
plt.plot(history_rnn.history['val_mae'], 'r-', label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %%
#  Plot Predictions vs Actuals
plt.figure(figsize=(20, 6))

# Train part
plt.plot( y_train_inv[:200], label='Train Actual', color='blue', marker='.', linewidth=1
)

plt.plot( train_predict_inv[:200], label='Train Predicted',color='cyan',
    linewidth=2
)

# Test part (shifted in time)
start_idx = len(y_train_inv[:200])

plt.plot( range(start_idx, start_idx + 200),  y_test_inv[:200], label='Test Actual', color='red', marker='.', linewidth=1
)

plt.plot(range(start_idx, start_idx + 200), test_predict_inv[:200],label='Test Predicted', color='orange',linewidth=2
)
plt.title('RNN Voltage Prediction vs Actual (PEMFC)', fontsize=14)
plt.xlabel('Time Step', fontsize=12)
plt.ylabel('Stack Voltage (V)', fontsize=12)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))

# Plot training data actual vs predicted
plt.plot(y_train_inv, label='Actual Train', color='blue')
plt.plot(train_predict_inv, label='Predicted Train', color='orange')

# Plot test data actual vs predicted
plt.plot(range(len(y_train_inv), len(y_train_inv) + len(y_test_inv)), y_test_inv, label='Actual Test', color='green')
plt.plot(range(len(y_train_inv), len(y_train_inv) + len(y_test_inv)), test_predict_inv, label='Predicted Test', color='red')

plt.title('RNN Predictions vs Actual Values', fontsize=16, fontweight='bold')
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Stock Voltage', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#  Plot results
plt.figure(figsize=(20,6))
plt.plot(y_train_inv[:200], label='Actual', color='red', marker='o')
plt.plot(test_predict_inv[:200], label='Predicted', color='blue', linestyle='--', marker='s')
plt.title('RNN Forecast vs Actual')
plt.xlabel('Time Step')
plt.ylabel('Stack Voltage')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # ================================
# #  Gated Recurrent Unit (GRU)
# # ================================

# %%
# Build GRU model
gru_model = Sequential()

# First GRU layer
gru_model.add(GRU(
    units=64,
    return_sequences=False,
    input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # (timesteps, features), input_shape=[None, 5 feature]
    dropout=0.2,
))

# Output layer
gru_model.add(Dense(1))

# Compile
gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse', metrics=["mae"]
)

# %%
# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train
history_gru = gru_model.fit(
    X_train_seq,
    y_train_seq,
    epochs=100,
    batch_size=32,
   validation_data=(X_val_seq, y_val_seq),
    callbacks=[early_stop],
    verbose=1,
    shuffle=False)

gru_model.summary()
# Out:
# Epoch 1/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - loss: 0.0071 - mae: 0.0422 - val_loss: 0.0172 - val_mae: 0.1118
# Epoch 2/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - loss: 0.0048 - mae: 0.0298 - val_loss: 0.0205 - val_mae: 0.1247
# Epoch 3/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 0.0058 - mae: 0.0323 - val_loss: 0.0200 - val_mae: 0.1228
# Epoch 4/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 0.0075 - mae: 0.0375 - val_loss: 0.0203 - val_mae: 0.1242
# Epoch 5/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 0.0083 - mae: 0.0418 - val_loss: 0.0189 - val_mae: 0.1189
# Epoch 6/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - loss: 0.0095 - mae: 0.0447 - val_loss: 0.0184 - val_mae: 0.1175
# Epoch 7/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 0.0109 - mae: 0.0490 - val_loss: 0.0186 - val_mae: 0.1188
# Epoch 8/100
# ...

# %%
# --- Make predictions ---
train_pred_gru = gru_model.predict(X_train_seq)
test_pred_gru  = gru_model.predict(X_test_seq)


train_pred_gru_inv = scaler_y.inverse_transform(train_pred_gru)
test_pred_gru_inv  = scaler_y.inverse_transform(test_pred_gru)

y_train_gru_inv = scaler_y.inverse_transform(y_train_seq.reshape(-1, 1))
y_test_gru_inv  = scaler_y.inverse_transform(y_test_seq.reshape(-1, 1))
# Out:
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 1320/1320 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %%
gru_df1 = pd.DataFrame(history_gru.history)
gru_df1.head()
# Out:
#        loss       mae  val_loss   val_mae
# 0  0.001773  0.020517  0.017151  0.111814
# 1  0.001323  0.018033  0.020506  0.124672
# 2  0.001646  0.020546  0.020001  0.122793
# 3  0.002149  0.023578  0.020262  0.124193
# 4  0.002626  0.027429  0.018860  0.118912

# %%
# Evaluation (GRU)
train_mae_gru  = mean_absolute_error(y_train_gru_inv, train_pred_gru_inv)
train_rmse_gru = np.sqrt(mean_squared_error(y_train_gru_inv, train_pred_gru_inv))

test_mae_gru  = mean_absolute_error(y_test_gru_inv, test_pred_gru_inv)
test_rmse_gru = np.sqrt(mean_squared_error(y_test_gru_inv, test_pred_gru_inv))

print(f"GRU Train MAE  : {train_mae_gru:.4f}")
print(f"GRU Train RMSE : {train_rmse_gru :.4f}")
print(f"GRU Test MAE   : {test_mae_gru:.4f}")
print(f"GRU Test RMSE  : {test_rmse_gru:.4f}")
# Out:
# GRU Train MAE  : 0.0465
# GRU Train RMSE : 0.0551
# GRU Test MAE   : 0.0324
# GRU Test RMSE  : 0.0344

# %%
gru_df = pd.DataFrame({
    "train_mae": [train_mae_gru],
    "train_rmse": [train_rmse_gru ],
    "test_mae": [test_mae_gru],
    "test_rmse": [test_rmse_gru]
})

gru_df.head()
# Out:
#    train_mae  train_rmse  test_mae  test_rmse
# 0   0.046526    0.055135   0.03243   0.034421

# %%
#  Plot training history
plt.figure(figsize=(20,5))
plt.plot(history_gru.history['loss'], label='Train Loss', color='blue')
plt.plot(history_gru.history['val_loss'], label='Validation Loss', color='red')
plt.title('GRU Model Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(history_gru.history['mae'], label='Train MAE', color='green')
plt.plot(history_gru.history['val_mae'], label='Validation MAE', color='orange')
plt.title('GRU Model MAE Over Epochs', fontsize=16)
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %%
#  Plot Predictions vs Actuals

plt.figure(figsize=(20, 6))


plt.plot( y_train_gru_inv[:200], label='Train Actual', color='blue', marker='.', linewidth=1)
plt.plot( train_pred_gru_inv[:200],label='Train Predicted (GRU)',color='cyan',linewidth=2)



start_idx = len(y_train_gru_inv[:200])

plt.plot(range(start_idx, start_idx + 200),y_test_gru_inv[:200],label='Test Actual', color='red', marker='.',linewidth=1)

plt.plot(range(start_idx, start_idx + 200), test_pred_gru_inv[:200], label='Test Predicted (GRU)', color='orange', linewidth=2)

# Plot settings
plt.title('GRU Stack Voltage Prediction vs Actuals (PEMFC)', fontsize=14)
plt.xlabel('Time Step', fontsize=12)
plt.ylabel('Stack Voltage (V)', fontsize=12)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))

# Train: Actual vs Predicted
plt.plot( y_train_gru_inv, label='Actual Train', color='blue', linewidth=1)
plt.plot( train_pred_gru_inv, label='Predicted Train (GRU)', color='orange', linewidth=2)


plt.plot(range(len(y_train_gru_inv), len(y_train_gru_inv) + len(y_test_gru_inv)), y_test_gru_inv, label='Actual Test', color='green', linewidth=1)
plt.plot( range(len(y_train_gru_inv), len(y_train_gru_inv) + len(test_pred_gru_inv)), test_pred_gru_inv, label='Predicted Test (GRU)', color='red', linewidth=2)

# Plot settings
plt.title('GRU Stack Voltage Prediction vs Actual Values (PEMFC)',
          fontsize=16, fontweight='bold')
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Stack Voltage (V)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # ================================
# # LSTM
# # ================================

# %% [markdown]
# Reference: Analytics Vidhya
#
# <img src="https://cdn-images-1.medium.com/v2/resize:fill:1600:480/gravity:fp:0.5:0.4/0*O_TqfQ4537oM4MH0.gif" style="width:1000px;height:550px;">
#
# <img src="https://miro.medium.com/v2/resize:fit:720/format:webp/1*APrZtnag0aXGztE9zl4iYg.png" style="width:1000px;height:550px;">

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000;
#             text-align: justify; color: black; font-size: 14px; padding: 15px;
#             background:#F2FFFF;">
#
#   <p style="font-size: 18px; color: #00ff0dff; font-family: cursive; line-height: 1.4;">
#         Time series data consists of sequences of observations recorded at specific points in time,
#         such as stock prices, weather measurements, or website traffic. Understanding patterns
#         and making predictions from such data is essential across many domains.
#     </p>
#
#   <h2 style="color:blue; font-family: cursive;">Where Traditional RNNs Fall Short:</h2>
#     <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         Standard Recurrent Neural Networks (RNNs) are effective for sequential data. However,
#         they struggle with learning long-term dependencies because information from earlier
#         in the sequence fades as new inputs are processed.
#     </p>
#
#   <h2 style="color:blue; font-family: cursive;">LSTM to the Rescue: Long Short-Term Memory</h2>
#     <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         Long Short-Term Memory (LSTM) networks are a specialized type of RNN designed to
#         overcome this limitation. Their advanced internal structure helps them retain
#         important information over long periods.
#     </p>
#
#    <h2 style="color:blue; font-family: cursive;">Key Components of an LSTM:</h2>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>1. Cell State:</strong> Acts like a long conveyor belt that carries information
#         through the entire sequence, allowing the LSTM to preserve important data for extended periods.
#     </p>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>2. Forget Gate:</strong> Decides what information from the previous cell state
#         should be forgotten or discarded, helping remove irrelevant or outdated information.
#    </p>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>3. Input Gate:</strong> Determines which new information from the current input
#         should be added to the cell state, filtering out unimportant details.
#     </p>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#        <strong>4. Output Gate:</strong> Controls what information from the cell state is used
#         to generate the output at each time step, influencing the model’s predictions.
#     </p>
#
#    <h2 style="color:blue; font-family: cursive;">How LSTMs Work with Time Series Data:</h2>
#
#   <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>1. Unfolding the Network:</strong> At each time step, the LSTM receives a new
#         data point from the time series.
#     </p>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>2. Processing with Memory:</strong> The LSTM processes both the current input and
#         the information carried in the cell state. The forget, input, and output gates work together
#         to control how information flows.
#   </p>
#
#   <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>3. Output and Update Memory:</strong> The LSTM produces an output (such as a prediction)
#         and updates the cell state for the next time step using the combined actions of all three gates.
#    </p>
#
#   <h2 style="color:blue; font-family: cursive;">Benefits of LSTMs for Time Series Analysis:</h2>
#
#    <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>1. Learning Long-Term Dependencies:</strong> LSTMs excel at capturing long-range
#         patterns such as trends and seasonality, which is critical for forecasting.
#     </p>
#
#   <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>2. Improved Prediction Accuracy:</strong> By effectively remembering important past data,
#         LSTMs generally outperform standard RNNs in time series forecasting.
#     </p>
#
#   <p style="font-size: 14px; color: #556b2f; font-family: cursive; line-height: 1.4;">
#         <strong>3. Wide Range of Applications:</strong> LSTMs are used in stock prediction, weather forecasting,
#         energy demand prediction, anomaly detection, NLP, and more.
#     </p>
#
#    <p style="font-size: 16px; color: Red; font-family: cursive; line-height: 1.4;">
#         Overall, LSTMs are powerful tools for time series analysis. Their ability to learn long-term
#         dependencies makes them extremely valuable for prediction and pattern recognition across many fields.
#     </p>
#
# </div>

# %%
model_lstm = Sequential()

model_lstm.add(LSTM(units=64,return_sequences=True, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model_lstm.add(LSTM(units=32,return_sequences=False))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(1))



model_lstm.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
# Early stopping
es = EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
history_lstm = model_lstm.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=100,
    batch_size=32,
    callbacks=[es],
    shuffle=False,
    verbose=1
)
model_lstm.summary()
# Out:
# Epoch 1/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 49s 20ms/step - loss: 0.0074 - mae: 0.0544 - val_loss: 0.0285 - val_mae: 0.1525
# Epoch 2/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 64s 12ms/step - loss: 0.0316 - mae: 0.0974 - val_loss: 0.0226 - val_mae: 0.1328
# Epoch 3/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.0276 - mae: 0.0953 - val_loss: 0.0217 - val_mae: 0.1296
# Epoch 4/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - loss: 0.0229 - mae: 0.0875 - val_loss: 0.0251 - val_mae: 0.1414
# Epoch 5/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.0217 - mae: 0.0867 - val_loss: 0.0221 - val_mae: 0.1312
# Epoch 6/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - loss: 0.0230 - mae: 0.0910 - val_loss: 0.0241 - val_mae: 0.1380
# Epoch 7/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - loss: 0.0244 - mae: 0.0951 - val_loss: 0.0218 - val_mae: 0.1301
# Epoch 8/100
# ...

# %%
lstm_df1 = pd.DataFrame(history_lstm.history)
lstm_df1.head()
# Out:
#        loss       mae  val_loss   val_mae
# 0  0.003431  0.037960  0.019471  0.121520
# 1  0.003789  0.039809  0.020247  0.124726
# 2  0.006091  0.047174  0.025539  0.142908
# 3  0.006994  0.048417  0.024819  0.140458
# 4  0.007944  0.053299  0.023529  0.136030

# %%
# --- Make predictions ---
train_pred_lstm = model_lstm.predict(X_train_seq)
test_pred_lstm  = model_lstm.predict(X_test_seq)


#  Inverse scaling
train_pred_inv_lstm = scaler_y.inverse_transform(train_pred_lstm)
test_pred_inv_lstm  = scaler_y.inverse_transform(test_pred_lstm)

y_train_inv_lstm = scaler_y.inverse_transform(y_train_seq)
y_test_inv_lstm  = scaler_y.inverse_transform(y_test_seq)
# Out:
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step
# 1320/1320 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %%
# --- Evaluation ---
train_mae_lstm = mean_absolute_error(y_train_inv_lstm, train_pred_inv_lstm)
train_rmse_lstm = np.sqrt(mean_squared_error(y_train_inv_lstm, train_pred_inv_lstm))

test_mae_lstm = mean_absolute_error(y_test_inv_lstm, test_pred_inv_lstm)
test_rmse_lstm = np.sqrt(mean_squared_error(y_test_inv_lstm, test_pred_inv_lstm))

print("Train MAE:", train_mae_lstm)
print("Train RMSE:", train_rmse_lstm)
print("Test MAE:", test_mae_lstm)
print("Test RMSE:", test_rmse_lstm)
# Out:
# Train MAE: 0.045295438632045416
# Train RMSE: 0.054121409124447704
# Test MAE: 0.032211142606386724
# Test RMSE: 0.034207870494231206

# %%
lsmt_df = pd.DataFrame({
    "train_mae": [train_mae_lstm],
    "train_rmse": [train_rmse_lstm],
    "test_mae": [test_mae_lstm],
    "test_rmse": [test_rmse_lstm]
})

lsmt_df.head()
# Out:
#    train_mae  train_rmse  test_mae  test_rmse
# 0   0.045295    0.054121  0.032211   0.034208

# %%
# --- Plot Loss ---
plt.figure(figsize=(20,5))
plt.plot(history_lstm.history['loss'], label='Train Loss', color='blue')
plt.plot(history_lstm.history['val_loss'], label='Validation Loss', color='red')
plt.title('LSTM Model Loss Over Epochs', fontsize=16, fontweight='bold')
plt.ylabel('Loss', fontsize=14)
plt.xlabel('Epochs', fontsize=14)
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)
plt.show()

# %%
# --- Plot MAE ---
plt.figure(figsize=(20,5))
plt.plot(history_lstm.history['mae'], 'g-', label='Training MAE')
plt.plot(history_lstm.history['val_mae'], 'r-', label='Validation MAE')
plt.title('LSTM Training and Validation MAE', fontsize=16, fontweight='bold')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,6))

# Plot training set
plt.plot(y_train_inv_lstm, label='Actual Train', color='blue')
plt.plot(train_pred_inv_lstm, label='Predicted Train', color='orange')

# Plot test set
plt.plot(np.arange(len(y_train_inv_lstm), len(y_train_inv_lstm)+len(y_test_inv_lstm)),y_test_inv_lstm,label='Actual Test',color='green'
)

plt.plot(np.arange(len(y_train_inv_lstm), len(y_train_inv_lstm)+len(y_test_inv_lstm)), test_pred_inv_lstm, label='Predicted Test', color='red'
)

plt.title('LSTM: Actual vs Predicted Electricity Cost', fontsize=16, fontweight='bold')
plt.xlabel('Time Step', fontsize=14)
plt.ylabel('stock voltage)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
#  Plot results
plt.figure(figsize=(20,6))
plt.plot(y_test_inv_lstm[:200], label='Actual', color='red', marker='o')
plt.plot(test_pred_inv_lstm[:200], label='Predicted', color='blue', linestyle='--', marker='s')
plt.title('LSTM Forecast vs Actual')
plt.xlabel('Time Step')
plt.ylabel('stok voltage')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(y_test_inv_lstm, label='Actual Voltage', color='black')
plt.plot(test_pred_inv_lstm, label='LSTM Prediction', color='blue')
plt.title("Degradation Trend Verification - LSTM")
plt.xlabel("Time Step (hours)")
plt.ylabel("Stack Voltage (V)")
plt.legend()
plt.show()

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Best Epochs
# </center></p></h1>

# %%
# Training & validation loss
tr_loss  = history_lstm.history['loss']
val_loss = history_lstm.history['val_loss']

# Best epoch (minimum validation loss)
best_epoch = np.argmin(val_loss) + 1
best_val_loss = np.min(val_loss)

print(f"Best Epoch        : {best_epoch}")
print(f"Best Val Loss     : {best_val_loss:.6f}")
# Out:
# Best Epoch        : 1
# Best Val Loss     : 0.019471

# %%
# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Optimizer</p>
# </div>

# %% [markdown]
# ![learning_rate](https://miro.medium.com/v2/resize:fit:1200/0*K0ltbXIgtNLEXsXN.png)
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Fmedium.com%2Foctavian-ai%2Fhow-to-use-the-learning-rate-finder-in-tensorflow-126210de9489&psig=AOvVaw2GiCBkU0T8pc8lbeGTmzhi&ust=1699876013893000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCKDF6OKxvoIDFQAAAAAdAAAAABAD)

# %%
learning_rate = 0.003
epochs = 250
batch_size = 32

input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])

def build_lstm_model(optimizer):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        LSTM(32),
        Dense(1)])

    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae'])
    return model



early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1)

# %%
lstm_adam = build_lstm_model(
    Adam(learning_rate=learning_rate))

history_lstm_adam = lstm_adam.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=1)
# Out:
# Epoch 1/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 37s 14ms/step - loss: 0.0394 - mae: 0.1532 - val_loss: 0.2007 - val_mae: 0.4265
# Epoch 2/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 0.0155 - mae: 0.0893 - val_loss: 0.1457 - val_mae: 0.3469
# Epoch 3/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 45s 15ms/step - loss: 0.0142 - mae: 0.0838 - val_loss: 0.1799 - val_mae: 0.4005
# Epoch 4/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 0.0128 - mae: 0.0784 - val_loss: 0.1739 - val_mae: 0.3958
# Epoch 5/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.0117 - mae: 0.0746 - val_loss: 0.1397 - val_mae: 0.3383
# Epoch 6/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 0.0114 - mae: 0.0727 - val_loss: 0.1058 - val_mae: 0.2888
# Epoch 7/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.0105 - mae: 0.0690 - val_loss: 0.1435 - val_mae: 0.3454
# Epoch 8/250
# ...

# %%
from tensorflow.keras.optimizers import SGD

lstm_sgd = build_lstm_model(
    SGD(learning_rate=learning_rate, momentum=0.9))

history_lstm_sgd = lstm_sgd.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=1)
# Out:
# Epoch 1/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 32s 12ms/step - loss: 0.0653 - mae: 0.2145 - val_loss: 0.1980 - val_mae: 0.4344
# Epoch 2/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - loss: 0.0359 - mae: 0.1555 - val_loss: 0.1058 - val_mae: 0.3019
# Epoch 3/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - loss: 0.0264 - mae: 0.1318 - val_loss: 0.1451 - val_mae: 0.3588
# Epoch 4/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - loss: 0.0254 - mae: 0.1294 - val_loss: 0.1685 - val_mae: 0.3904
# Epoch 5/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 43s 13ms/step - loss: 0.0245 - mae: 0.1268 - val_loss: 0.1239 - val_mae: 0.3313
# Epoch 6/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - loss: 0.0235 - mae: 0.1238 - val_loss: 0.0848 - val_mae: 0.2691
# Epoch 7/250
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - loss: 0.0226 - mae: 0.1211 - val_loss: 0.1254 - val_mae: 0.3336
# Epoch 8/250
# ...

# %%
plt.figure(figsize=(14, 6))

plt.plot(history_lstm_adam.history['mae'], label='LSTM Adam – Train MAE')
plt.plot(history_lstm_adam.history['val_mae'], label='LSTM Adam – Val MAE')

plt.plot(history_lstm_sgd.history['mae'], label='LSTM SGD – Train MAE')
plt.plot(history_lstm_sgd.history['val_mae'], label='LSTM SGD – Val MAE')

plt.title('LSTM MAE Comparison (Adam vs SGD)', fontsize=15, fontweight='bold')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Add Early Stop-different learning rates
# </p>
# </div>

# %% [markdown]
# ![earlystop.png](https://miro.medium.com/v2/resize:fit:1242/1*W368qtCQlCYmt6YlwIYnJg.png)

# %%
learning_rates = [0.001, 0.003, 0.01]
epochs = 100
batch_size = 32

input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])

# %%
def build_lstm(lr):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        LSTM(32),
        Dense(1)])
    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss='mse',
        metrics=['mae'])
    return model

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True)

# %%
histories = {}

for lr in learning_rates:
    print(f"Training with learning rate = {lr}")

    model = build_lstm(lr)

    history = model.fit(
        X_train_seq, y_train_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=1,
        shuffle=False)

    histories[lr] = history
# Out:
# Training with learning rate = 0.001
# Epoch 1/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 0.0036 - mae: 0.0295 - val_loss: 0.0213 - val_mae: 0.1274
# Epoch 2/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 46s 19ms/step - loss: 0.0061 - mae: 0.0333 - val_loss: 0.0233 - val_mae: 0.1357
# Epoch 3/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 49s 20ms/step - loss: 0.0140 - mae: 0.0516 - val_loss: 0.0266 - val_mae: 0.1463
# Epoch 4/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 0.0178 - mae: 0.0625 - val_loss: 0.0272 - val_mae: 0.1483
# Epoch 5/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - loss: 0.0198 - mae: 0.0645 - val_loss: 0.0266 - val_mae: 0.1466
# Epoch 6/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 33s 14ms/step - loss: 0.0211 - mae: 0.0687 - val_loss: 0.0269 - val_mae: 0.1474
# Epoch 7/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - loss: 0.0210 - mae: 0.0693 - val_loss: 0.0268 - val_mae: 0.1472
# Epoch 8/100
# ...

# %%
plt.figure(figsize=(12,5))

for lr, history in histories.items():
    plt.plot(history.history['val_mae'], label=f'LR = {lr}')

plt.title('LSTM Validation MAE vs Learning Rate')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Add Dropout Layer</p>
# </div>

# %% [markdown]
# ![dropout.png](https://i.stack.imgur.com/SbXq1.jpg)
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Fstackoverflow.com%2Fquestions%2F34597316%2Fwhy-input-is-scaled-in-tf-nn-dropout-in-tensorflow&psig=AOvVaw1l_917bIGSEasDy2uybjlj&ust=1699876094112000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCNDmtomyvoIDFQAAAAAdAAAAABAI)

# %%
learning_rate = 0.003
epochs = 100
batch_size = 32

input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])

# %%
def lstm_no_dropout(dropout_rate=None):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        LSTM(32),
        Dense(1)
    ])
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
def lstm_with_dropout(dropout_rate=0.2):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True)

# %%
# No Dropout
model_no = lstm_no_dropout()
history_no = model_no.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=1,
    shuffle=False
)

# With Dropout
model_do = lstm_with_dropout()
history_do = model_do.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 33s 12ms/step - loss: 0.0023 - mae: 0.0216 - val_loss: 0.0179 - val_mae: 0.1152
# Epoch 2/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - loss: 0.0076 - mae: 0.0340 - val_loss: 0.0204 - val_mae: 0.1248
# Epoch 3/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 46s 14ms/step - loss: 0.0121 - mae: 0.0455 - val_loss: 0.0249 - val_mae: 0.1408
# Epoch 4/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 0.0174 - mae: 0.0621 - val_loss: 0.0259 - val_mae: 0.1441
# Epoch 5/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - loss: 0.0195 - mae: 0.0708 - val_loss: 0.0261 - val_mae: 0.1446
# Epoch 6/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - loss: 0.0190 - mae: 0.0666 - val_loss: 0.0258 - val_mae: 0.1437
# Epoch 7/100
# 2431/2431 ━━━━━━━━━━━━━━━━━━━━ 47s 15ms/step - loss: 0.0187 - mae: 0.0675 - val_loss: 0.0260 - val_mae: 0.1443
# Epoch 8/100
# ...

# %%
plt.figure(figsize=(12,5))

plt.plot(history_no.history['val_mae'], label='No Dropout')
plt.plot(history_do.history['val_mae'], label='With Dropout')

plt.title('LSTM Validation MAE: Dropout vs No Dropout')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> Fine Tune</p>
# </div>

# %%
def objective(trial):

    clear_session()

    # Hyperparameters
    units = trial.suggest_int("units", 32, 128, step=32)
    dropout = trial.suggest_float("dropout", 0.0, 0.5, step=0.1)
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [16, 32])

    # Build model
    model = Sequential()
    model.add(LSTM(units, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
    model.add(Dense(1))

    model.compile(optimizer=Adam(lr), loss="mse", metrics=["mae"])

    early_stop = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True,
    verbose=0)

    # Train
    history = model.fit(
        X_train_seq, y_train_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=50,
        batch_size=batch_size,  callbacks=[early_stop],
        verbose=0,
        shuffle=False
    )

    # Return validation loss
    return min(history.history["val_loss"])

# %%
# Run Optuna
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)

print("Best params:", study.best_params)
# Out:
# [I 2026-01-17 03:29:46,357] A new study created in memory with name: no-name-71672fb1-d6ef-4442-9f8b-b0afff4cd32f
# [I 2026-01-17 03:41:51,325] Trial 0 finished with value: 0.01762649416923523 and parameters: {'units': 128, 'dropout': 0.0, 'lr': 0.0004890308230677481, 'batch_size': 16}. Best is trial 0 with value: 0.01762649416923523.
# [I 2026-01-17 03:51:57,811] Trial 1 finished with value: 0.01748925819993019 and parameters: {'units': 128, 'dropout': 0.2, 'lr': 0.0006107409359932093, 'batch_size': 16}. Best is trial 1 with value: 0.01748925819993019.
# [I 2026-01-17 03:56:46,369] Trial 2 finished with value: 0.017240069806575775 and parameters: {'units': 64, 'dropout': 0.0, 'lr': 0.007670732240061903, 'batch_size': 16}. Best is trial 2 with value: 0.017240069806575775.
# ...

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> Comparasion Models</p>
# </div>

# %%
df_compare = pd.DataFrame({
    "Model": ["RNN", "LSTM", "GRU"],
    "Train MAE": [train_mae_rnn, train_mae_lstm, train_mae_gru],
    "Train RMSE": [train_rmse_rnn, train_rmse_lstm, train_rmse_gru],
    "Test MAE": [test_mae_rnn, test_mae_lstm, test_mae_gru],
    "Test RMSE": [test_rmse_rnn, test_rmse_lstm, test_rmse_gru]
})

print(df_compare)
# Out:
#   Model  Train MAE  Train RMSE  Test MAE  Test RMSE
# 0   RNN   0.008436    0.011639  0.051944   0.054370
# 1  LSTM   0.045295    0.054121  0.032211   0.034208
# 2   GRU   0.046526    0.055135  0.032430   0.034421

# %%
plt.figure(figsize=(12, 5))
plt.bar(df_compare["Model"], df_compare["Test RMSE"], color=['blue','green','orange'])
plt.title("Test RMSE Comparison")
plt.show()

plt.figure(figsize=(12, 5))
plt.bar(df_compare["Model"], df_compare["Test MAE"], color=['blue','green','orange'])
plt.title("Test MAE Comparison")
plt.show()

# %%
plt.figure(figsize=(20, 6))

plt.plot(y_test_inv, label='Actual', color='black', linewidth=2)

plt.plot(test_predict_inv, label='Predicted (RNN)', color='orange', linewidth=2)

plt.plot(test_pred_inv_lstm, label='Predicted (LSTM)', color='blue', linewidth=2)

plt.plot(test_pred_gru_inv, label='Predicted (GRU)', color='green', linewidth=2)

plt.title('Actual vs Predicted (RNN / LSTM / GRU)', fontsize=16, fontweight='bold')
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Stack Voltage', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> RUL calculation</p>
# </div>

# %%
#  Failure threshold
# Example threshold (96% of initial voltage)
threshold = 0.96 * y_train_inv_lstm[0][0]

# %%
threshold = 3.2028

# %%
failure_indices = np.where(test_pred_inv_lstm <= threshold)[0]

if len(failure_indices) == 0:
    # No failure predicted in test period
    failure_index_pred = None
    predicted_RUL = None
    print("🔴 No failure predicted in the test period.")
else:
    # First predicted failure
    failure_index_pred = failure_indices[0]
    predicted_RUL = len(test_pred_inv_lstm) - failure_index_pred

    print("🟢 Predicted failure time index:", failure_index_pred)
    print("🟢 Predicted RUL (hours):", predicted_RUL)
# Out:
# 🔴 No failure predicted in the test period.

# %%
#  Voltage check
if failure_index_pred is not None:
    print("Voltage at predicted failure:", test_pred_inv_lstm[failure_index_pred][0])
    print("Threshold:", threshold)

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px"> Conclusion</p>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Sequence Models and RNN/LSTM</title>
# </head>
# <body>
#
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #008000;
#             text-align: justify; color: black; font-size: 14px; padding: 15px;
#             background:#F2FFFF;">
#   <h2>Conclusion</h2>
#
#   <p>
#         This work presents a deep learning–based prognostic framework for predicting the long-term degradation trend and remaining useful life (RUL) of five-cell proton exchange membrane fuel cell (PEMFC) stacks under static and dynamic loading conditions. Three recurrent neural network architectures—vanilla RNN, LSTM, and GRU—were developed using Keras and optimized through systematic hyperparameter tuning with Hyperband pruning via the Optuna framework.
#  </p>
#
#  <p>
#         The models were evaluated using the IEEE PHM 2014 Data Challenge dataset. Results show that all three architectures can capture long-term degradation trends, but gated recurrent models (LSTM and GRU) significantly outperform the vanilla RNN. The GRU model achieved the best overall accuracy with a test MAE of approximately <strong>0.015</strong>, followed by the LSTM with <strong>0.025</strong>, while the RNN showed weaker performance with an MAE of <strong>0.045</strong>. These results indicate that GRU and LSTM better track the degradation trajectory, especially during rapid voltage decline periods, while the vanilla RNN tends to lag behind.
#     </p>
#
# <p>
#         For the FC1 dataset, the LSTM model demonstrated strong predictive performance with an RMSE of <strong>1.26×10⁻³ V</strong> and an RUL prediction relative error (RE) of <strong>0.0425×10⁻¹</strong>. The results confirm that gated recurrent architectures provide more reliable and efficient prognostic capabilities compared to standard RNNs for PEMFC degradation prediction.
#     </p>
#
# <p>
#         Future work will focus on improving model robustness by incorporating additional stack-level measurements, integrating prognostic models with state estimators for unobserved variables, and developing online predictive maintenance strategies using real-time degradation and RUL estimation.
#  </p>
#
# </div>
#
# <br>
#
# <div style="border-radius: 5px; font-family: cursive; border: 2px solid #000;
#             text-align: left; color: black; font-size: 14px; padding: 15px;
#             background:#F9F9F9;">
#     <h3>Brief Summary (RNN vs LSTM vs GRU)</h3>
#     <ul>
#         <li><strong>RNN:</strong> Basic sequential model; struggles with long-term dependencies.</li>
#         <li><strong>LSTM:</strong> Uses gates to remember long-term patterns; better accuracy and stability.</li>
#         <li><strong>GRU:</strong> Similar to LSTM but simpler; best performance in this study with highest accuracy.</li>
#     </ul>
# </div>
#
# </body>
# </html>
